# %% [markdown]
# # Prepare the dataset

# %%
import kagglehub
import shutil

# Download latest version
path = kagglehub.dataset_download("allahhitler/ocr-synthetic-dataset")

print("Path to dataset files:", path)

shutil.copytree(path, "/content/data", dirs_exist_ok=True)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/allahhitler/ocr-synthetic-dataset/versions/1
# '/content/data'

# %% [markdown]
# # Split the data

# %%
import os
from pathlib import Path

# %cd data
def split_dataset(image_dir, labels_file, train_ratio=0.8, val_ratio=0.1):
    """
    Split dataset into training, validation, and testing sets.

    Args:
        image_dir (str): Path to directory containing images
        labels_file (str): Path to labels.txt file
        train_ratio (float): Ratio of training data (default: 0.8 = 80%)
        val_ratio (float): Ratio of validation data (default: 0.1 = 10%)
    """

    # Read labels file
    with open(labels_file, 'r') as f:
        lines = f.readlines()

    # Parse labels
    image_labels = {}
    for line in lines:
        if line.strip():
            filename, label = line.strip().split(' ', 1)
            image_labels[filename] = label

    # Get sorted list of image files
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.jpg')])
    total_images = len(image_files)

    # Calculate split points
    train_end = int(total_images * train_ratio)
    val_end = int(total_images * (train_ratio + val_ratio))

    # Create directories
    base_dirs = {
        "train": Path("train"),
        "val": Path("val"),
        "test": Path("test")
    }

    for d in base_dirs.values():
        (d / "images").mkdir(parents=True, exist_ok=True)

    # Initialize label lists
    label_files = {
        "train": [],
        "val": [],
        "test": []
    }

    # Split the dataset
    for i, image_file in enumerate(image_files):
        src_path = Path(image_dir) / image_file

        if i < train_end:
            split = "train"
        elif i < val_end:
            split = "val"
        else:
            split = "test"

        dest_path = base_dirs[split] / "images" / image_file
        shutil.copy2(src_path, dest_path)
        label_files[split].append(f"{image_file} {image_labels[image_file]}")

    # Write label files
    for split, lines in label_files.items():
        with open(base_dirs[split] / "labels.txt", "w") as f:
            f.write("\n".join(lines))

    # Print summary
    print("Dataset split completed!")
    print(f"Total images: {total_images}")
    print(f"Training set: {train_end} images ({train_ratio:.0%})")
    print(f"Validation set: {val_end - train_end} images ({val_ratio:.0%})")
    print(f"Testing set: {total_images - val_end} images ({1 - train_ratio - val_ratio:.0%})")
    print("\nDirectory structure:")
    for split in ["train", "val", "test"]:
        print(f"{split}/")
        print(f"├── labels.txt")
        print(f"└── images/")
    print("\nAll done!")


# Configuration
IMAGE_DIR = "images"       # Directory containing your images
LABELS_FILE = "labels.txt" # Path to labels.txt
TRAIN_RATIO = 0.8          # 80% for training
VAL_RATIO = 0.1            # 10% for validation (remaining 10% for testing)

split_dataset(IMAGE_DIR, LABELS_FILE, TRAIN_RATIO, VAL_RATIO)

# %cd ..

# !mkdir checkpoints/
# Out:
# /content/data
# Dataset split completed!
# Total images: 100000
# Training set: 80000 images (80%)
# Validation set: 10000 images (10%)
# Testing set: 10000 images (10%)
#
# Directory structure:
# train/
# ├── labels.txt
# └── images/
# val/
# ├── labels.txt
# └── images/
# test/
# ├── labels.txt
# └── images/
#
# All done!
# /content
# mkdir: cannot create directory ‘checkpoints/’: File exists

# %% [markdown]
# # Configurations

# %%
config = {
    'data_dir': 'data',
    'img_width': 100,
    'img_height': 32,
    'map_to_seq_hidden': 64,
    'rnn_hidden': 256,
    'leaky_relu': False,
    'max_label_len': 32,
}

train_config = {
    'epochs': 2,
    'train_batch_size': 32,
    'eval_batch_size': 512,
    'lr': 0.0005,
    'show_interval': 10,
    'valid_interval': 500,
    'save_interval': 500,
    'cpu_workers': 4,
    'valid_max_iter': 100,
    'decode_method': 'beam_search',
    'beam_size': 10,
    'checkpoints_dir': 'checkpoints',
    # New checkpoint-related settings
    'max_checkpoints_to_keep': 3,
    'resume_training': True,           # Auto-resume from latest checkpoint
    'checkpoint_path': None,           # Specific checkpoint to load (optional)
    'save_every_epoch': False,         # Save at end of each epoch
    'save_h5_weights': True,           # Also save H5 for compatibility
}
train_config.update(config)

evaluate_config = {
    'eval_batch_size': 512,
    'cpu_workers': 4,
    'decode_method': 'beam_search',
    'beam_size': 10,
    # Updated checkpoint loading for evaluation
    'checkpoint_path': 'checkpoints',  # Can be specific file or directory
    'resume_training': False,           # Set to False for evaluation
}
evaluate_config.update(config)

# %%
config
# Out:
# {'data_dir': 'data',
#  'img_width': 100,
#  'img_height': 32,
#  'map_to_seq_hidden': 64,
#  'rnn_hidden': 256,
#  'leaky_relu': False,
#  'max_label_len': 32}

# %%
train_config
# Out:
# {'epochs': 2,
#  'train_batch_size': 32,
#  'eval_batch_size': 512,
#  'lr': 0.0005,
#  'show_interval': 10,
#  'valid_interval': 500,
#  'save_interval': 500,
#  'cpu_workers': 4,
#  'valid_max_iter': 100,
#  'decode_method': 'beam_search',
#  'beam_size': 10,
#  'checkpoints_dir': 'checkpoints',
#  'max_checkpoints_to_keep': 3,
#  'resume_training': True,
#  'checkpoint_path': None,
#  'save_every_epoch': False,
#  'save_h5_weights': True,
#  'data_dir': 'data',
#  'img_width': 100,
#  'img_height': 32,
#  'map_to_seq_hidden': 64,
#  'rnn_hidden': 256,
#  'leaky_relu': False,
#  'max_label_len': 32}

# %%
evaluate_config
# Out:
# {'eval_batch_size': 512,
#  'cpu_workers': 4,
#  'decode_method': 'beam_search',
#  'beam_size': 10,
#  'checkpoint_path': 'checkpoints',
#  'resume_training': False,
#  'data_dir': 'data',
#  'img_width': 100,
#  'img_height': 32,
#  'map_to_seq_hidden': 64,
#  'rnn_hidden': 256,
#  'leaky_relu': False,
#  'max_label_len': 32}

# %% [markdown]
# # `Dataset` class

# %%
import os
import tensorflow as tf
import numpy as np
from PIL import Image
from enum import Enum
from typing import Optional, List, Tuple, Union

class DatasetMode(Enum):
    TRAIN = 'train'
    VAL = 'val'
    TEST = 'test'

class Synth90kDataset:
    # 0–9, a–z, A–Z  (indices start at 1; 0 is reserved for CTC blank)
    CHARS = ''.join([chr(i) for i in range(ord('0'), ord('9')+1)]) + \
            ''.join([chr(i) for i in range(ord('a'), ord('z')+1)]) + \
            ''.join([chr(i) for i in range(ord('A'), ord('Z')+1)])
    CHAR2LABEL = {c: i+1 for i, c in enumerate(CHARS)}
    LABEL2CHAR = {i+1: c for i, c in enumerate(CHARS)}

    def __init__(
        self,
        root_dir: Optional[str] = None,
        mode: Optional[DatasetMode] = None,
        paths: Optional[List[str]] = None,
        img_height: int = 32,
        img_width: int = 100
    ):
        if root_dir and mode and not paths:
            self.paths, self.texts = self._load_from_raw_files(root_dir, mode)
        elif not root_dir and not mode and paths:
            self.paths = paths
            self.texts = None

        self.img_height = img_height
        self.img_width = img_width

    def _load_from_raw_files(self, root_dir: str, mode: DatasetMode) -> Tuple[List[str], List[str]]:
        """
        Load image file paths and their corresponding text labels from label files.

        This method reads a label file containing filename–text pairs, constructs
        the full image paths, and extracts the associated text labels. Each line
        in the label file must follow the format:

            filename text_label

        Args:
            root_dir (str): Root directory where the dataset is stored.
            mode (DatasetMode): Dataset split to load (e.g., TRAIN, VAL, TEST).

        Returns:
            tuple[list[str], list[str]]:
                - paths: List of full paths to image files in the format
                  "data/{mode}/images/{filename}".
                - texts: List of text labels corresponding to each image path.

        Example:
            If root_dir = "/dataset", mode = TRAIN, and the file
            "/dataset/train/labels.txt" contains:
                img1.jpg hello
                img2.jpg world

            The method will return:
                paths = ["data/train/images/img1.jpg", "data/train/images/img2.jpg"]
                texts = ["hello", "world"]
        """

        paths_file = f"{mode.value}/labels.txt"
        paths: List[str] = []
        texts: List[str] = []

        # Read the labels file and parse each line
        with open(os.path.join(root_dir, paths_file), 'r') as fr:
            for line in fr.readlines():
                # Path contains filenames and text are the labels
                line = line.strip()
                if not line:
                    continue
                # Split at first whitespace only (labels can be single token; this keeps it robust)
                parts = line.split(maxsplit=1)
                if len(parts) != 2:
                    continue
                filename, text = parts[0], parts[1]
                img_path = os.path.join(root_dir, mode.value, 'images', filename)
                paths.append(img_path)
                texts.append(text)
        return paths, texts

    def __len__(self) -> int:
        return len(self.paths)

    def create_tf_dataset(self, batch_size: int = 32, training: bool = True) -> tf.data.Dataset:
      """
      Create a TensorFlow Dataset for efficient data loading and preprocessing.

      This method generates a tf.data.Dataset pipeline that can be used for training
      or validation. It handles both cases with and without text labels, applying
      appropriate batching and preprocessing optimizations.
      """
      def generator():
          """
          Generator function that yields individual preprocessed samples.

          Yields:
              tuple or ndarray: Single processed sample from _process_single_item
          """
          for i in range(len(self.paths)):
              yield self._process_single_item(i)

      # Define output signature using tf.TensorSpec based on whether text labels are available
      if self.texts:
          output_signature = (
              tf.TensorSpec(shape=(self.img_height, self.img_width, 1), dtype=tf.float32),
              tf.TensorSpec(shape=(None,), dtype=tf.int32),
              tf.TensorSpec(shape=(), dtype=tf.int32),
          )
      else:
          output_signature = tf.TensorSpec(
              shape=(self.img_height, self.img_width, 1), dtype=tf.float32
          )

      # Create TensorFlow dataset from generator using tf.data.Dataset.from_generator()
      dataset = tf.data.Dataset.from_generator(generator, output_signature=output_signature)


      # Apply appropriate batching strategy based on text presence
      if self.texts:
          # Call dataset.padded_batch for variable-length text sequences
          # padded batch for variable-length label sequences
          dataset = dataset.padded_batch(
              batch_size,
              padded_shapes=(
                  (self.img_height, self.img_width, 1),  # image
                  (None,),  # target sequence (pad on right)
                  (),      # length (scalar)
              ),
              padding_values=(
                  tf.constant(0.0, dtype=tf.float32), # image padding (0 maps to mid-range after [-1,1])
                  tf.constant(0, dtype=tf.int32), # label padding
                  tf.constant(0, dtype=tf.int32), # length padding (won't be used)
              ),
              drop_remainder=training # only drop last incomplete batch during training
          )
          # Apply training-specific optimizations
          if training:
              # Prefetch batches for improved pipeline performance
              dataset = dataset.prefetch(tf.data.AUTOTUNE)
      else:
          # Simple batching for datasets without text labels
          dataset = dataset.batch(batch_size)

      return dataset

    def _process_single_item(self, index: int) -> Union[Tuple[np.ndarray, np.ndarray, int], np.ndarray]:
      """
      Process a single data item by loading, preprocessing image and text.

      This method handles the complete preprocessing pipeline for a single data sample,
      including image loading, resizing, normalization, and text label conversion.
      It includes error handling for corrupted images and recursive fallback.
      """
      path = self.paths[index]

      try:
          # Load image and convert to grayscale
          image = Image.open(path).convert('L')
      except IOError:
          # Handle corrupted images by recursively trying the next sample
          print('Corrupted image for %d' % index)
          return self._process_single_item((index + 1) % len(self.paths))

      # Expect image with shape (img_height, img_width, 1) and pixel values in [-1, 1] (use bilinear interpolation to resize)
      # Resize with bilinear interpolation to (W, H) in PIL, then normalize to [-1, 1]
      image = image.resize((self.img_width, self.img_height), resample=Image.BILINEAR)
      image = np.asarray(image, dtype=np.float32) / 255.0            # [0,1]
      image = image * 2.0 - 1.0                                      # [-1,1]
      image = np.expand_dims(image, axis=-1)                         # (H, W, 1)

      # Process text labels if available
      if self.texts:
          text = self.texts[index]
          # Expect target as a list of integer labels mapped from each character in text (target_length is the length of the target list)
          # Map characters to indices (skip unknown chars)
          target = [self.CHAR2LABEL[c] for c in text if c in self.CHAR2LABEL]
          target_length = len(target)
          # Return image with text labels and sequence length
          return image, np.array(target, dtype=np.int32), target_length
      else:
          # Return only the preprocessed image when no text labels are available
          return image

# %%
# For checking
Synth90kDataset(root_dir="/content/data",
                mode=DatasetMode.TRAIN,
                img_height=config["img_width"],
                img_width=config["img_height"]).create_tf_dataset(batch_size=32).element_spec
# Out:
# (TensorSpec(shape=(32, 100, 32, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(32, None), dtype=tf.int32, name=None),
#  TensorSpec(shape=(32,), dtype=tf.int32, name=None))

# %% [markdown]
# # `CRNN` Class

# %%
from tensorflow.keras import layers

class CRNN(tf.keras.Model):
    """
    Convolutional Recurrent Neural Network (CRNN) for sequence recognition.

    This model combines CNN feature extraction with RNN sequence modeling,
    commonly used for tasks like text recognition in images. The architecture
    follows the CRNN design with CNN backbone followed by bidirectional LSTMs.

    Args:
        img_channel (int): Number of channels in input images (1 for grayscale, 3 for RGB)
        img_height (int): Height of input images (must be divisible by 16)
        img_width (int): Width of input images (must be divisible by 4)
        num_class (int): Number of output classes (typically characters + 1 for blank)
        map_to_seq_hidden (int, optional): Hidden units in the mapping layer between CNN and RNN.
                                          Defaults to 64.
        rnn_hidden (int, optional): Number of hidden units in each LSTM layer. Defaults to 256.
        leaky_relu (bool, optional): Whether to use LeakyReLU instead of ReLU. Defaults to False.
        **kwargs: Additional keyword arguments passed to the parent class.

    Architecture:
        - CNN Backbone: 7 convolutional layers with pooling for feature extraction
        - Map to Sequence: Dense layer to transform CNN features to sequence format
        - RNN: Two bidirectional LSTM layers for sequence modeling
        - Output: Dense layer for logits

    Input Shape:
        (batch_size, img_height, img_width, img_channel)

    Output Shape:
        (width, batch_size, num_class) - Transposed for CTC loss compatibility

    Note:
        - Input image dimensions must satisfy: height % 16 == 0 and width % 4 == 0
        - Uses bidirectional LSTMs for better context understanding
    """

    def __init__(self, img_channel, img_height, img_width, num_class,
                 map_to_seq_hidden=64, rnn_hidden=256, leaky_relu=False, **kwargs):
        super().__init__(**kwargs)

        # Store model configuration parameters
        self.img_channel = img_channel
        self.img_height = img_height
        self.img_width = img_width
        self.num_class = num_class
        self.map_to_seq_hidden = map_to_seq_hidden
        self.rnn_hidden = rnn_hidden
        self.leaky_relu = leaky_relu

        # Build CNN backbone for feature extraction
        self.cnn = self._build_cnn_backbone(img_channel, leaky_relu)

        # Dense layer to map CNN features to sequence format for RNN
        # Map CNN features (flattened per time step) → hidden
        self.fc_map = layers.Dense(self.map_to_seq_hidden, name="map_to_seq")

        # Two bidirectional LSTM layers for sequence modeling
        self.rnn1 = layers.Bidirectional(
            layers.LSTM(self.rnn_hidden, return_sequences=True), name="bilstm_1")
        self.rnn2 = layers.Bidirectional(
            layers.LSTM(self.rnn_hidden, return_sequences=True), name="bilstm_2")

        # Output layer for class probability prediction
        # (no activation; CTC expects logits)
        self.classifier = layers.Dense(self.num_class, name="logits")


    def _act(self):
        # Returns the correct activation layer depending on whether leaky_relu=True
        return layers.LeakyReLU(alpha=0.2) if self.leaky_relu else layers.ReLU()

    def _build_cnn_backbone(self, img_channel, leaky_relu):
        """
        Build the CNN backbone for feature extraction.

        The CNN consists of 7 convolutional layers with pooling and batch normalization.
        It progressively reduces spatial dimensions while increasing feature depth.

        Args:
            img_channel (int): Number of input image channels
            leaky_relu (bool): Whether to use LeakyReLU activation

        Returns:
            tf.keras.Sequential: CNN backbone model

        Architecture Details:
            - Layers 0-1: 64 and 128 filters with 2x2 max pooling
            - Layers 2-3: 256 filters with special (2,1) pooling
            - Layers 4-5: 512 filters with batch normalization and (2,1) pooling
            - Layer 6: 512 filters with valid padding (reduces width by 1)

        Note:
            - Input height must be divisible by 16 due to pooling strides
            - Input width must be divisible by 4 due to pooling strides
        """
        # Validate input dimensions meet architectural requirements
        assert self.img_height % 16 == 0
        assert self.img_width % 4 == 0

        model = tf.keras.Sequential()

        # Define input shape
        model.add(layers.InputLayer(input_shape=(self.img_height, self.img_width, img_channel)))

        # Layer 0: 64 filters, 3x3 convolution, ReLU/LeakyReLU, 2x2 max pooling
        model.add(layers.Conv2D(64, 3, padding='same', use_bias=True))
        model.add(self._act())
        model.add(layers.MaxPool2D(pool_size=(2,2), strides=(2,2))) # (H/2, W/2, 64)

        # Layer 1: 128 filters, 3x3 convolution, ReLU/LeakyReLU, 2x2 max pooling
        model.add(layers.Conv2D(128, 3, padding='same', use_bias=True))
        model.add(self._act())
        model.add(layers.MaxPool2D(pool_size=(2,2), strides=(2,2))) # (H/4, W/4, 128)

        # Layer 2: 256 filters, 3x3 convolution, ReLU/LeakyReLU (no pooling)
        model.add(layers.Conv2D(256, 3, padding='same', use_bias=True))
        model.add(self._act()) # (H/4, W/4, 256)

        # Layer 3: 256 filters, 3x3 convolution, ReLU/LeakyReLU, (2,1) max pooling
        model.add(layers.Conv2D(256, 3, padding='same', use_bias=True))
        model.add(self._act())
        model.add(layers.MaxPool2D(pool_size=(2,1), strides=(2,1))) # (H/8, W/4, 256)

        # Layer 4: 512 filters with batch normalization, ReLU/LeakyReLU
        model.add(layers.Conv2D(512, 3, padding='same', use_bias=True))
        model.add(layers.BatchNormalization())
        model.add(self._act()) # (H/8, W/4, 512)

        # Layer 5: 512 filters with batch normalization, ReLU/LeakyReLU, (2,1) max pooling
        model.add(layers.Conv2D(512, 3, padding='same', use_bias=True))
        model.add(layers.BatchNormalization())
        model.add(self._act())
        model.add(layers.MaxPool2D(pool_size=(2,1), strides=(2,1))) # (H/16, W/4, 512)

        # Layer 6: 512 filters, 2x2 convolution with valid padding, ReLU/LeakyReLU
        model.add(layers.Conv2D(512, 2, padding='valid', use_bias=True))
        model.add(self._act()) # (H/16 - 1, W/4 - 1, 512)

        return model

    def build(self, input_shape):
        """
        Build the model by explicitly constructing all layers.

        This method ensures all layers are properly built with the correct
        input shapes before the first forward pass.

        Args:
            input_shape: Shape of the input tensor
        """
        # Explicitly build each component to ensure proper weight initialization
        super(CRNN, self).build(input_shape)

    def call(self, images, training=False):
        """
        Forward pass of the CRNN model.

        Processes input images through CNN feature extraction, sequence mapping,
        RNN sequence modeling, and final classification layers.

        Args:
            images (tf.Tensor): Input image tensor of shape
                               (batch_size, height, width, channels)
            training (bool, optional): Whether the model is in training mode.
                                      Defaults to False.

        Returns:
            tf.Tensor: Output tensor of shape (width, batch_size, num_class)
                       Transposed for compatibility with CTC loss functions

        Processing Steps:
            1. CNN feature extraction
            2. Map to sequence with dense layer
            3. Process through two bidirectional LSTM layers
            4. Apply dense layer for classification

        Note: You may need to reshape to match dimension
        """
        # CNN feature extraction: (batch, height, width, channels)
        output = self.cnn(images, training=training)
        # Reshape for sequence processing along width:
        # (B, W', H'*C) — time dimension is width
        B, Hp, Wp, C = tf.unstack(tf.shape(output))

        # transpose to (B, W', H', C) then flatten H' and C
        output = tf.transpose(output, [0, 2, 1, 3]) # (B, W', H', C)
        output = tf.reshape(output, [B, Wp, -1]) # (B, W', H'*C)

        # Map CNN features to sequence format
        output = self.fc_map(output) # (B, W', map_to_seq_hidden)

        # Process through bidirectional LSTM layers
        # RNN layers (keep sequence)
        output = self.rnn1(output, training=training) # (B, W', 2*rnn_hidden)
        output = self.rnn2(output, training=training) # (B, W', 2*rnn_hidden)

        # Final classification layer: (batch, width, num_class)
        # Classifier to logits
        output = self.classifier(output) # (B, W', num_class)
        # Transpose to time-major for CTC: (T, B, C)
        output = tf.transpose(output, [1, 0, 2])
        return output

# %%
crnn = CRNN(1, config["img_height"], config["img_width"], len(Synth90kDataset.LABEL2CHAR) + 1,
                map_to_seq_hidden=config['map_to_seq_hidden'],
                rnn_hidden=config['rnn_hidden'],
                leaky_relu=config['leaky_relu'])

crnn.build(input_shape=(None, config["img_height"], config["img_height"], 1))
crnn.summary()

crnn.cnn.summary()
# Out:
# Model: "crnn_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_7 (Sequential)       │ (None, 1, 24, 512)     │     5,552,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ map_to_seq (Dense)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_1 (Bidirectional)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_2 (Bidirectional)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logits (Dense)                  │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,552,896 (21.18 MB)
#  Trainable params: 5,550,848 (21.17 MB)
#  Non-trainable params: 2,048 (8.00 KB)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_49 (Conv2D)              │ (None, 32, 100, 64)    │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_49 (ReLU)                 │ (None, 32, 100, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 16, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_50 (Conv2D)              │ (None, 16, 50, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_50 (ReLU)                 │ (None, 16, 50, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 8, 25, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_51 (Conv2D)              │ (None, 8, 25, 256)     │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_51 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_52 (Conv2D)              │ (None, 8, 25, 256)     │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_52 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 4, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_53 (Conv2D)              │ (None, 4, 25, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_53 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_54 (Conv2D)              │ (None, 4, 25, 512)     │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_54 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (None, 2, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_55 (Conv2D)              │ (None, 1, 24, 512)     │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_55 (ReLU)                 │ (None, 1, 24, 512)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,552,896 (21.18 MB)
#  Trainable params: 5,550,848 (21.17 MB)
#  Non-trainable params: 2,048 (8.00 KB)

# %% [markdown]
# # `CTCLoss` Class

# %%
class CTCLoss(tf.keras.losses.Loss):
    """
    Connectionist Temporal Classification (CTC) Loss for sequence recognition tasks.

    This loss function is designed for sequence-to-sequence tasks where the alignment
    between inputs and labels is unknown, such as speech recognition or handwritten
    text recognition. It computes the negative log probability of the correct sequence.

    The CTC loss handles variable-length sequences by considering all possible alignments
    between the input sequence (model predictions) and the target sequence (labels).

    Inherits from:
        tf.keras.losses.Loss

    Typical Use Cases:
        - Optical Character Recognition (OCR)
        - Speech Recognition
        - Handwriting Recognition
        - Any sequence labeling task with unaligned sequences

    Note:
        - Assumes blank index is 0 (standard for CTC)
        - Handles variable-length sequences automatically
        - Uses logits (unnormalized scores) rather than probabilities
        - Computes mean loss across the batch
    """

    def call(self, y_true, y_pred):
        """
        Compute the CTC loss between true labels and predicted logits.

        This method prepares the inputs for TensorFlow's CTC loss function by
        calculating the necessary sequence lengths and formatting the data
        appropriately for the CTC algorithm.

        Args:
            y_true (tf.Tensor): True labels tensor of shape (batch_size, max_label_length)
                               containing integer class labels. Padded with zeros for
                               shorter sequences.
            y_pred (tf.Tensor): Predicted logits tensor of shape
                               (batch_size, sequence_length, num_classes) containing
                               unnormalized scores for each class at each time step.

        Returns:
            tf.Tensor: Scalar tensor representing the mean CTC loss across the batch.

        Note:
            - The blank index (for CTC transitions) is set to 0
            - Label length is computed by counting non-zero elements in y_true
            - Input length is assumed to be the full sequence length of predictions
            - Logits are expected in batch-major format (batch, time, classes)
        """

        # Compute CTC loss using TensorFlow's built-in function `tf.nn.ctc_loss`
        # lengths
        y_true = tf.cast(y_true, tf.int32)
        label_length = tf.math.count_nonzero(y_true, axis=1, dtype=tf.int32) # (B,)
        B = tf.shape(y_pred)[0]
        T = tf.shape(y_pred)[1]
        logit_length = tf.fill([B], T) # (B,)

        # Convert dense padded labels -> SparseTensor (drop pads)
        # (only keep the first label_length tokens of each row)
        ragged = tf.RaggedTensor.from_tensor(y_true, lengths=label_length) # [B, None]
        labels_sparse = ragged.to_sparse() # SparseTensor

        # CTC loss expects logits (NOT softmax). We pass batch-major logits.
        loss = tf.nn.ctc_loss(
            labels=labels_sparse,
            logits=y_pred,
            label_length=label_length,
            logit_length=logit_length,
            logits_time_major=False, # because y_pred is (B, T, C)
            blank_index=0
        )

        # Return mean loss across all samples in the batch
        return tf.reduce_mean(loss)

# %% [markdown]
# # CTC decoders

# %%
from collections import defaultdict
from scipy.special import logsumexp

# Constants
NINF = -1 * float('inf')  # Negative infinity for log probability calculations
DEFAULT_EMISSION_THRESHOLD = 0.01  # Default threshold for emission probabilities

def _reconstruct(labels, blank=0):
    """
    Reconstruct labels by removing consecutive duplicates and blank tokens.

    This function applies the CTC collapse rules to remove repeated characters
    and blank tokens from a sequence, producing the final decoded output.

    Args:
        labels (list): Sequence of integer labels containing duplicates and blanks
        blank (int, optional): Index of the blank token. Defaults to 0.

    Returns:
        list: Reconstructed sequence with consecutive duplicates removed and blanks filtered out

    Example:
        >>> _reconstruct([0, 1, 1, 0, 2, 2, 2, 0, 3], blank=0)
        [1, 2, 3]
        >>> _reconstruct([1, 1, 2, 2, 1, 1], blank=0)
        [1, 2, 1]

    Note:
        - Implements the standard CTC collapse rule: remove duplicates and blanks
        - Only consecutive duplicates are removed, non-consecutive duplicates remain
    """
    new_labels = []
    previous = None
    # Remove consecutive duplicates
    for l in labels:
        if l != previous:
            new_labels.append(l)
            previous = l
    # Remove blank tokens
    new_labels = [l for l in new_labels if l != blank]
    return new_labels

def greedy_decode(emission_log_prob, blank=0, **kwargs):
    """
    Greedy decoding for CTC sequences.

    This decoder selects the most probable character at each time step independently,
    then applies CTC reconstruction rules. It's fast but may not find the optimal sequence.

    Args:
        emission_log_prob (np.ndarray): Log probability matrix of shape (length, num_classes)
        blank (int, optional): Index of the blank token. Defaults to 0.
        **kwargs: Additional arguments (ignored for greedy decoding)

    Returns:
        list: Decoded sequence of labels

    Time Complexity: O(T × C) where T is sequence length, C is number of classes
    Space Complexity: O(T)

    Example:
        >>> emission = np.log([[0.1, 0.7, 0.2], [0.3, 0.4, 0.3], [0.8, 0.1, 0.1]])
        >>> greedy_decode(emission, blank=0)
        [1, 1, 0]  # After reconstruction: [1]

    Note:
        - Fastest decoding method but suboptimal for difficult sequences
        - Does not consider multiple possible alignments
        - Suitable for when the probability distribution is peaked
    """

    # Select most probable character at each time step
    best = np.argmax(emission_log_prob, axis=1).tolist() #length T
    # Apply CTC reconstruction rules using _reconstruct()
    labels = _reconstruct(best, blank=blank)

    return labels

def beam_search_decode(emission_log_prob, blank=0, **kwargs):
    """
    Beam search decoding for CTC sequences.

    This decoder maintains multiple candidate sequences (beams) and expands them
    at each time step, keeping only the top-k most probable sequences.

    Args:
        emission_log_prob (np.ndarray): Log probability matrix of shape (length, num_classes)
        blank (int, optional): Index of the blank token. Defaults to 0.
        **kwargs: Additional arguments including:
            beam_size (int): Number of beams to maintain
            emission_threshold (float, optional): Log probability threshold for pruning

    Returns:
        list: Most probable decoded sequence

    Time Complexity: O(T × C × B) where T=length, C=classes, B=beam_size
    Space Complexity: O(B × T)

    Example:
        >>> emission = np.log([[0.1, 0.7, 0.2], [0.3, 0.4, 0.3], [0.8, 0.1, 0.1]])
        >>> beam_search_decode(emission, blank=0, beam_size=5)
        [1, 2]  # Best sequence found by beam search

    Note:
        - More accurate than greedy decoding but slower
        - beam_size controls the trade-off between accuracy and speed
        - emission_threshold prunes low-probability paths to improve efficiency
    """
    beam_size = kwargs['beam_size']
    emission_threshold = kwargs.get('emission_threshold', np.log(DEFAULT_EMISSION_THRESHOLD))

    length, class_count = emission_log_prob.shape

    # Initialize with empty sequence and zero log probability
    beams = [([], 0)]  # Each beam is (sequence, accumulated_log_prob)

    # Iterate through each time step
    for t in range(length):
        new_beams = []
        # Expand each existing beam with all possible next characters
        for prefix, accumulated_log_prob in beams:
            for c in range(class_count):
                log_prob = emission_log_prob[t, c]
                # Prune paths with very low emission probability
                if log_prob < emission_threshold:
                    continue
                # Create new sequence and update probability
                new_prefix = prefix + [c]
                new_accu_log_prob = accumulated_log_prob + log_prob
                new_beams.append((new_prefix, new_accu_log_prob))

        # Keep only the top-k beams by probability
        new_beams.sort(key=lambda x: x[1], reverse=True)
        beams = new_beams[:beam_size]

    # Merge beams that produce the same reconstructed sequence
    total_accu_log_prob = {}
    for prefix, accu_log_prob in beams:
        labels = tuple(_reconstruct(prefix, blank))
        # Use logsumexp to combine probabilities of different alignments to same sequence
        total_accu_log_prob[labels] = \
            logsumexp([accu_log_prob, total_accu_log_prob.get(labels, NINF)])

    # Select the sequence with highest probability
    labels_beams = [(list(labels), accu_log_prob)
                    for labels, accu_log_prob in total_accu_log_prob.items()]
    labels_beams.sort(key=lambda x: x[1], reverse=True)
    labels = labels_beams[0][0]

    return labels

def prefix_beam_decode(emission_log_prob, blank=0, **kwargs):
    """
    Prefix beam search decoding for CTC sequences.

    Args:
        emission_log_prob (np.ndarray): Log probability matrix of shape (length, num_classes)
        blank (int, optional): Index of the blank token. Defaults to 0.
        **kwargs: Additional arguments including:
            beam_size (int): Number of beams to maintain
            emission_threshold (float, optional): Log probability threshold for pruning

    Returns:
        list: Most probable decoded sequence

    ------------------------------------------------------------------------
    HOW THIS ALGORITHM WORKS:

    1. Each prefix (partial output sequence) keeps TWO log-probabilities:
         - p_b(prefix): probability of all paths that end with a BLANK
         - p_nb(prefix): probability of all paths that end with a NON-BLANK

    2. At each time step t, for every active prefix:
         (a) Emit BLANK:
             - Stay on the same prefix (no new label appended).
             - p_b'(prefix) += log_p[blank] + logsumexp(p_b, p_nb)

         (b) Emit NON-BLANK label c:
             - If c == last(prefix):
                 # same label as last
                 - repeat without appending:
                     p_nb'(prefix) += log_p[c] + p_nb(prefix)
                 - append same label again (requires blank before):
                     p_nb'(prefix + c) += log_p[c] + p_b(prefix)
             - Else (c != last(prefix)):
                 - append new label:
                     p_nb'(prefix + c) += log_p[c] + logsumexp(p_b, p_nb)

    3. All updates are accumulated with logsumexp because multiple
       paths can land on the same (prefix, ending state).

    4. After processing all labels for time t:
         - Keep only the top `beam_size` prefixes ranked by
           logsumexp(p_b, p_nb).

    5. After the final time step:
         - Choose the prefix with the largest total probability
           logsumexp(p_b, p_nb) as the best decoded sequence.

    Key points:
      - Initialization: p_b(()) = 0, p_nb(()) = -inf
      - Must separate blank vs non-blank ending states
      - Handle repeated labels carefully
      - Use logsumexp for combining probabilities
      - Prune to beam_size at each time step

    Complexity:
      - O(T × C × B) time where T=time steps, C=classes, B=beam size
      - O(B) space (top beams at each step)
    """

    # Initialize beams with empty prefix and (p_b=0, p_nb=-inf)
    # For each time step:
    #   - create defaultdict for new beams
    #   - loop over current beams
    #   - update new beams for blank and each label
    #   - prune to top beam_size
    # Return the prefix with max total probability

    beam_size = kwargs['beam_size']
    emission_threshold = kwargs.get('emission_threshold', np.log(DEFAULT_EMISSION_THRESHOLD))

    length, class_count = emission_log_prob.shape

    # Beams store (prefix, (prob_blank, prob_non_blank))
    beams = [(tuple(), (0, NINF))]  # Start with empty prefix

    for t in range(length):
        new_beams_dict = defaultdict(lambda: (NINF, NINF))

        for prefix, (lp_b, lp_nb) in beams:
            for c in range(class_count):
                log_prob = emission_log_prob[t, c]
                if log_prob < emission_threshold:
                    continue

                end_t = prefix[-1] if prefix else None
                new_lp_b, new_lp_nb = new_beams_dict[prefix]

                if c == blank:
                    # Extending with blank: both blank and non-blank can transition to blank
                    new_lp_b = logsumexp([new_lp_b, log_prob + logsumexp([lp_b, lp_nb])])
                    new_beams_dict[prefix] = (new_lp_b, new_lp_nb)
                    
                    continue

                if c == end_t:
                    # Extending with same character as last: only non-blank can extend
                    new_lp_nb = logsumexp([new_lp_nb, log_prob + lp_nb])
                    new_beams_dict[prefix] = (new_lp_b, new_lp_nb)

                new_prefix = prefix + (c,)
                new_lp_b, new_lp_nb = new_beams_dict[new_prefix]

                if c != end_t:
                    # New character: both blank and non-blank can extend to new character
                    new_lp_nb = logsumexp([new_lp_nb, log_prob + logsumexp([lp_b, lp_nb])])
                    new_beams_dict[new_prefix] = (new_lp_b, new_lp_nb)

                else:
                    # Same character but not consecutive: only blank can extend
                    new_lp_nb = logsumexp([new_lp_nb, log_prob + lp_b])
                    new_beams_dict[new_prefix] = (new_lp_b, new_lp_nb)

        # Select top beams by total probability (blank + non-blank)
        beams = sorted(new_beams_dict.items(), key=lambda x: logsumexp(x[1]), reverse=True)
        beams = beams[:beam_size]

    # Return the best prefix
    labels = list(beams[0][0])
    return labels

def ctc_decode(
    log_probs: np.ndarray,
    label2char: dict | None = None,
    blank: int = 0,
    method: str = "beam_search",
    beam_size: int = 10,
    input_lengths: np.ndarray | None = None,
    return_strings: bool = False,
):
    """
    Decode a batch of log-prob sequences (B, T, C) into label sequences.
    - Iterates over the batch dimension (B), passing (Ti, C) to the decoder.
    - Supports optional per-sample input_lengths (Ti). If None, uses full T.
    - Normalizes different decoder return shapes (tuple, beams, single seq).
    - If label2char and return_strings=True, also returns strings.

    Returns:
        preds  (List[np.ndarray[int]] or List[str] if return_strings=True)
        (If your decoders expose scores and you need them, extend this to also return scores.)
    """
    # Expected shape: (B, T, C)
    emissions = np.asarray(log_probs)
    assert emissions.ndim == 3, f"log_probs must be 3D (B,T,C), got {emissions.shape}"
    B, T, C = emissions.shape

    # Choose decoder
    decoders = {
        "greedy": greedy_decode,
        "beam_search": beam_search_decode,
        "prefix_beam_search": prefix_beam_decode,
    }
    if method not in decoders:
        raise KeyError(f"Unknown decoding method: {method}. Available: {list(decoders.keys())}")
    decoder = decoders[method]

    # Per-sample lengths
    if input_lengths is None:
        input_lengths = np.full((B,), T, dtype=int)
    else:
        input_lengths = np.asarray(input_lengths).astype(int)
        assert input_lengths.shape == (B,), f"input_lengths must be shape (B,), got {input_lengths.shape}"

    preds = []
    for b in range(B):
        Ti = int(input_lengths[b])
        Ti = max(0, min(Ti, T))  # clamp
        emission_bt = emissions[b, :Ti, :]  # (Ti, C)

        # Call decoder. Different implementations may return:
        #  - sequence only,
        #  - (sequence, score),
        #  - [beam1, beam2, ...], possibly with scores elsewhere.
        out = decoder(emission_bt, blank=blank, beam_size=beam_size)

        # Normalize to a single best sequence of ints
        if isinstance(out, tuple) and len(out) >= 1:
            seq = out[0]
        else:
            seq = out

        # If beams (list of sequences), take top-1
        if isinstance(seq, list):
            if len(seq) == 0:
                seq = np.asarray([], dtype=int)
            else:
                # If it's a list of ints -> good; if it's a list of lists -> take first beam
                if isinstance(seq[0], (list, np.ndarray)):
                    seq = np.asarray(seq[0], dtype=int)
                else:
                    seq = np.asarray(seq, dtype=int)
        elif isinstance(seq, np.ndarray):
            seq = seq.astype(int)
        else:
            # Scalar or unknown -> coerce
            seq = np.asarray(seq, dtype=int)

        preds.append(seq)

    if label2char is not None and return_strings:
        preds_str = []
        for seq in preds:
            # only map known labels (skip blank and unseen ids)
            s = "".join(label2char.get(int(i), "") for i in seq if int(i) != blank)
            preds_str.append(s)
        return preds_str

    return preds

# %% [markdown]
# # Training

# %%
from typing import Any, Dict, List, Iterable, Tuple, Optional
from tqdm import tqdm

def evaluate(
    model: tf.keras.Model,
    dataloader,
    criterion,
    max_iter: int | None = None,
    decode_method: str = "beam_search",
    beam_size: int = 10,
) -> Dict[str, float | List[Tuple[str, str]]]:
    """
    Evaluate the model on a given dataloader.

    Returns:
        - 'loss': float
            Average loss over all evaluated samples.
        - 'acc': float
            Sequence-level (exact match) accuracy.
        - 'wrong_cases': List[Tuple[str, str]]
            Each element is a tuple (ground_truth_text, predicted_text)
            for a sample where the prediction did not match exactly.
    """
    total_count = 0
    total_loss = 0.0
    total_correct = 0
    wrong_cases: List[Tuple[str, str]] = []

    total = max_iter if max_iter < len(list(dataloader)) else len(list(dataloader))
    pbar = tqdm(total=total, desc="Evaluate")

    for i, batch in enumerate(dataloader):
        if max_iter is not None and i >= max_iter:
            break
        # Forward pass: CRNN returns time-major (T,B,C) → make batch-major (B,T,C)
        images, targets, target_lengths = batch
        B = int(images.shape[0])
        logits_TBC = model(images, training=False)
        logits_BTC = tf.transpose(logits_TBC, [1, 0, 2]) # [B,T,C]

        # Compute CTCLoss (batch-major)
        batch_loss = criterion(y_true=targets, y_pred=logits_BTC)

        # Decode predictions (ctc_decode expects log-probs)
        log_probs = tf.nn.log_softmax(logits_BTC, axis=-1).numpy()  # (B,T,C)
        input_lengths = np.full((B,), log_probs.shape[1], dtype=int)
        preds_str = ctc_decode(
            log_probs,
            label2char=Synth90kDataset.LABEL2CHAR,
            blank=0,
            method=decode_method,
            beam_size=beam_size,
            input_lengths=input_lengths,
            return_strings=True,
        )

        # Ground-truth (strip padding via target_lengths)
        gts_str = []
        for b in range(B):
            L = int(target_lengths[b].numpy() if isinstance(target_lengths, tf.Tensor) else target_lengths[b])
            tgt_row = targets[b].numpy() if isinstance(targets, tf.Tensor) else targets[b]
            s = "".join(Synth90kDataset.LABEL2CHAR.get(int(x), "") for x in tgt_row[:L] if int(x) != 0)
            gts_str.append(s)

        # Compare predictions with ground truth & update stats (sequence-level accuracy, only count as correct if the whole sequence is correct)
        for gt, pred in zip(gts_str, preds_str):
            total_count += 1
            if gt == pred:
                total_correct += 1
            else:
                wrong_cases.append((gt, pred))

        # Accumulate loss as sum over samples (so we can divide by total_count later)
        total_loss += float(batch_loss.numpy()) * B

        pbar.update(1)

    pbar.close()

    accuracy = total_correct / total_count if total_count > 0 else 0.0
    avg_loss = total_loss / total_count if total_count > 0 else 0.0
    return {"loss": avg_loss, "acc": accuracy, "wrong_cases": wrong_cases}

# %%
from __future__ import annotations
import abc, os
from typing import Any, Dict, Optional, Iterable, Tuple
import tensorflow as tf

class BaseTrainer(abc.ABC):
    """Minimal reusable trainer skeleton (SRP-friendly).

    Subclasses override:
      - build_datasets()
      - build_model()
      - build_optimizer()
      - build_loss()
      - train_step(batch)
      - evaluate_model()

    Optional hooks:
      - on_epoch_start(epoch), on_epoch_end(epoch), on_step_end(step, loss)
    """

    def __init__(self, cfg: Dict[str, Any]):
        self.cfg = cfg
        self.global_step = 1

        self.model: Optional[tf.keras.Model] = None
        self.optimizer: Optional[tf.keras.optimizers.Optimizer] = None
        self.criterion = None

        self.train_ds: Optional[Iterable] = None
        self.valid_ds: Optional[Iterable] = None
        self.metrics = {"train_loss": tf.keras.metrics.Mean(name="train_loss")}

        # Checkpoint management
        self.ckpt = None
        self.ckpt_manager = None

    # ----------------- build phase -----------------
    @abc.abstractmethod
    def build_datasets(self) -> Tuple[tf.data.Dataset, tf.data.Dataset]:
        """Return (train_ds, valid_ds)."""
        raise NotImplementedError

    @abc.abstractmethod
    def build_model(self) -> tf.keras.Model:
        raise NotImplementedError

    @abc.abstractmethod
    def build_optimizer(self) -> tf.keras.optimizers.Optimizer:
        raise NotImplementedError

    @abc.abstractmethod
    def build_loss(self):
        raise NotImplementedError

    # ----------------- train/eval steps -----------------
    @abc.abstractmethod
    @tf.function
    def train_step(self, batch) -> tf.Tensor:
        raise NotImplementedError

    @abc.abstractmethod
    def evaluate_model(self) -> Dict[str, Any]:
        raise NotImplementedError

    # ----------------- optional helpers/hooks -----------------
    def forward(self, images: tf.Tensor, training: bool) -> tf.Tensor:
        return self.model(images, training=training)

    def compute_loss(self, logits: tf.Tensor, batch) -> tf.Tensor:
        raise NotImplementedError

    def on_epoch_start(self, epoch: int) -> None:
        pass

    def on_epoch_end(self, epoch: int) -> None:
        pass

    def on_step_end(self, step: int, loss_value: float) -> None:
        pass

    # ----------------- environment/setup -----------------
    def seed_and_determinism(self) -> None:
        tf.random.set_seed(self.cfg.get("seed", 42))
        try:
            tf.config.experimental.enable_op_determinism()
        except Exception:
            pass

    def setup_checkpoint(self) -> None:
        os.makedirs(self.cfg['checkpoints_dir'], exist_ok=True)
        self.ckpt = tf.train.Checkpoint(
            step=tf.Variable(1, dtype=tf.int64),
            model=self.model,
            optimizer=self.optimizer,
            global_step=tf.Variable(1, dtype=tf.int64),
        )
        self.ckpt_manager = tf.train.CheckpointManager(
            checkpoint=self.ckpt,
            directory=self.cfg['checkpoints_dir'],
            max_to_keep=self.cfg.get('max_checkpoints_to_keep', 3),
        )

    def save_checkpoint(self, step: int, eval_stats: Optional[Dict[str, Any]] = None) -> str:
        if self.ckpt_manager is None:
            raise RuntimeError("Checkpoint manager not initialized. Call setup_checkpoint() first.")
        self.ckpt.step.assign(step)
        self.ckpt.global_step.assign(self.global_step)
        save_path = self.ckpt_manager.save(checkpoint_number=step)
        print(f"[Checkpoint] Saved: {save_path} (global_step: {self.global_step})")

        if self.cfg.get('save_h5_weights', False):
            h5_path = f"{self.cfg['checkpoints_dir']}/model_{step:06d}.weights.h5"
            self.model.save_weights(h5_path)
            print(f"[Checkpoint] H5 weights saved: {h5_path}")
        return save_path

    def restore_checkpoint(self, checkpoint_path: Optional[str] = None) -> bool:
        if self.ckpt is None:
            raise RuntimeError("Checkpoint not initialized. Call setup_checkpoint() first.")
        try:
            if checkpoint_path:
                self.ckpt.restore(checkpoint_path)
                print(f"[Checkpoint] Restored from specific checkpoint: {checkpoint_path}")
            else:
                if self.ckpt_manager.latest_checkpoint:
                    self.ckpt.restore(self.ckpt_manager.latest_checkpoint)
                    self.global_step = int(self.ckpt.global_step.numpy())
                    print(f"[Checkpoint] Restored from latest: {self.ckpt_manager.latest_checkpoint}")
                    print(f"[Checkpoint] Resuming from global_step: {self.global_step}")
                else:
                    print("[Checkpoint] No checkpoint found. Starting from scratch.")
                    return False
            return True
        except Exception as e:
            print(f"[Checkpoint] Failed to restore checkpoint: {e}")
            return False

    def get_checkpoint_info(self) -> Dict[str, Any]:
        if self.ckpt_manager is None:
            return {"available": False}
        return {
            "available": bool(self.ckpt_manager.latest_checkpoint),
            "latest_checkpoint": self.ckpt_manager.latest_checkpoint,
            "checkpoints": self.ckpt_manager.checkpoints if hasattr(self.ckpt_manager, 'checkpoints') else [],
        }

    # ----------------- explicit lifecycle steps -----------------
    def prepare(self) -> None:
        """Seed & build all components; setup checkpoint manager."""
        self.seed_and_determinism()
        self.train_ds, self.valid_ds = self.build_datasets()
        self.model = self.build_model()
        self.optimizer = self.build_optimizer()
        self.criterion = self.build_loss()
        self.setup_checkpoint()

    def restore_from_cfg(self) -> bool:
        """Read restoration policy from cfg and restore."""
        if self.ckpt is None or self.ckpt_manager is None:
            raise RuntimeError("Call prepare() before restore.")
        if self.cfg.get("resume_training", False):
            return self.restore_checkpoint()
        if self.cfg.get("checkpoint_path"):
            return self.restore_checkpoint(self.cfg["checkpoint_path"])
        return False

    def restore_from_path(self, checkpoint_path: str) -> bool:
        """Programmatic restore entrypoint (SRP)."""
        if self.ckpt is None or self.ckpt_manager is None:
            raise RuntimeError("Call prepare() before restore.")
        return self.restore_checkpoint(checkpoint_path)

    # ----------------- training only -----------------
    def train_loop(self) -> None:
        """Pure training loop. Assumes prepare() (and optional restore) already ran."""
        if any(x is None for x in [self.train_ds, self.valid_ds, self.model, self.optimizer, self.criterion]):
            raise RuntimeError("Trainer not prepared. Call prepare() first.")
        epochs = self.cfg["epochs"]
        show_interval = self.cfg["show_interval"]
        valid_interval = self.cfg["valid_interval"]
        save_interval = self.cfg["save_interval"]

        for epoch in range(1, epochs + 1):
            print(f"\n===== Epoch {epoch} =====")
            self.metrics["train_loss"].reset_state()
            self.on_epoch_start(epoch)

            for batch in self.train_ds:
                loss = self.train_step(batch)
                self.metrics["train_loss"](loss)

                if self.global_step % show_interval == 0:
                    avg = float(self.metrics["train_loss"].result().numpy())
                    print(f"[Step {self.global_step}] batch loss: {float(loss.numpy()):.4f} | running avg loss: {avg:.4f}")

                if self.global_step % valid_interval == 0:
                    eval_stats = self.evaluate_model()
                    if self.global_step % save_interval == 0:
                        self.save_checkpoint(self.global_step, eval_stats)

                self.on_step_end(self.global_step, float(loss.numpy()))
                self.global_step += 1

            print(f"Epoch {epoch} train loss: {float(self.metrics['train_loss'].result().numpy()):.4f}")
            self.on_epoch_end(epoch)

            if self.cfg.get('save_every_epoch', False):
                self.save_checkpoint(self.global_step)

    # ----------------- thin facade (optional) -----------------
    def fit(self, *, auto_prepare: bool = True) -> None:
        """
        SRP-compliant: training only.
        - If auto_prepare=True: runs prepare() (no restore) before training.
        """
        if auto_prepare:
            self.prepare()
        self.train_loop()

# %%
class CRNNTrainer(BaseTrainer):
    """
    CRNN + CTC trainer with small functions.

    Key TODOs:
      1) build_datasets()
      2) build_model()
      3) build_optimizer()
      4) build_loss()
      5) compute_loss()
      6) train_step()
      7) evaluate_model()
    """

    def __init__(self, cfg: Dict[str, Any]):
        super().__init__(cfg)
        self.img_h = cfg["img_height"]
        self.img_w = cfg["img_width"]
        self.reload_checkpoint = cfg.get("reload_checkpoint", "")

    # ----------------- BUILD PHASE -----------------
    def build_datasets(self) -> Tuple[tf.Data.Dataset, tf.Data.Dataset]:
        """
        Create train/valid tf.data.Datasets.
        Must yield tuples (images, targets, target_lengths).
          images: float32 [B, H, W, 1]
          targets: int32  [B, T_label]
          target_lengths: int32 [B]
        """
        data_dir = self.cfg["data_dir"]
        train_batch = self.cfg["train_batch_size"]
        eval_batch = self.cfg["eval_batch_size"]

        # Prepare datasets with correct shapes/dtypes
        data_dir   = self.cfg["data_dir"]
        train_batch = int(self.cfg["train_batch_size"])
        eval_batch  = int(self.cfg["eval_batch_size"])

        train_set = Synth90kDataset(
            root_dir=data_dir,
            mode=DatasetMode.TRAIN,
            img_height=self.img_h,
            img_width=self.img_w,
        )
        valid_set = Synth90kDataset(
            root_dir=data_dir,
            mode=DatasetMode.VAL,
            img_height=self.img_h,
            img_width=self.img_w,
        )

        train_ds = train_set.create_tf_dataset(batch_size=train_batch, training=True)
        valid_ds = valid_set.create_tf_dataset(batch_size=eval_batch,  training=False)

        return train_ds, valid_ds

    def build_model(self) -> tf.keras.Model:
        """
        Instantiate CRNN with correct num_class and hyperparams.
        Sanity check by running one batch and printing shapes.
        """
        num_class = int(self.cfg.get("num_class",
            self.cfg.get("num_classes", len(Synth90kDataset.CHARS) + 1)))
        print(f"[Build] num_classes={num_class}")
        model = CRNN(
            img_channel=1,
            img_height=self.img_h,
            img_width=self.img_w,
            num_class=num_class,
            map_to_seq_hidden=int(self.cfg.get("map_to_seq_hidden", 64)),
            rnn_hidden=int(self.cfg.get("rnn_hidden", 256)),
            leaky_relu=bool(self.cfg.get("leaky_relu", False)),
        )

        # eager sanity pass on a single batch
        sample_images, _, _ = next(iter(self.train_ds))
        out = model(sample_images)
        print(f"[Sanity] input: {sample_images.shape} -> logits: {out.shape}")

        # model summaries
        model.build(input_shape=(None, self.img_h, self.img_w, 1))
        model.summary()
        if hasattr(model, "cnn"):
            print("\n[Backbone] CNN")
            model.cnn.summary()

        # load weights if specified
        if self.reload_checkpoint:
            weights_path = self.reload_checkpoint.replace(".pt", ".h5")
            try:
                model.load_weights(weights_path)
                print(f"[Init] Loaded weights from {weights_path}")
            except Exception as e:
                print(f"[Init] Failed to load weights from {weights_path}: {e}")

        return model

    def build_optimizer(self) -> tf.keras.optimizers.Optimizer:
        """
        Choose and configure optimizer.
        """
        lr = float(self.cfg["lr"])
        optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
        return optimizer

    def build_loss(self):
        """
        Return CTCLoss() instance or a thin wrapper.
        """
        criterion = CTCLoss()
        return criterion

    # ----------------- HELPER OVERRIDES -----------------

    def compute_loss(self, logits: tf.Tensor, batch) -> tf.Tensor:
        """
        Implement CTC loss call.

        Inputs:
          logits: float32 [B, T, C] (batch-major)
          batch: (images, targets, target_lengths)
            targets: int32 [B, U] with -1 or padding tokens (depends on dataset)
            target_lengths: int32 [B]

        CTCLoss in this project expects batch-major logits [B,T,C].
        """
        _, targets, _ = batch
        loss = self.criterion(y_true=targets, y_pred=logits)
        return loss

    # ----------------- TRAIN / EVAL -----------------
    @tf.function
    def train_step(self, batch) -> tf.Tensor:
        """
        TODO:
        - run forward pass (training=True)
        - compute loss
        - backprop: grads = tape.gradient(...)
        - clip gradients
        - optimizer.apply_gradients(...)
        - return loss
        """
        images, _, _ = batch
        with tf.GradientTape() as tape:
            # Model returns time-major (T,B,C); transpose to batch-major (B,T,C)
            logits_time_major = self.model(images, training=True)
            logits = tf.transpose(logits_time_major, [1, 0, 2])
            loss = self.compute_loss(logits, batch)

        grads = tape.gradient(loss, self.model.trainable_variables)
        clipped_grads, _ = tf.clip_by_global_norm(grads, 5.0)
        self.optimizer.apply_gradients(zip(clipped_grads, self.model.trainable_variables))
        return loss

    def evaluate_model(self) -> Dict[str, Any]:
        """
        Use provided evaluate() helper OR write a small loop that:
          - runs forward on valid_ds
          - accumulates CTCLoss
          - optionally decodes for accuracy
        """
        stats = evaluate(
            self.model,
            self.valid_ds,
            self.criterion,
            max_iter=self.cfg["valid_max_iter"],
            decode_method=self.cfg["decode_method"],
            beam_size=self.cfg["beam_size"],
        )
        # Keep logs compact
        pstats = {k: (float(v) if isinstance(v, (int, float)) else v) for k, v in stats.items()}
        print(f"[Eval @ step {self.global_step}] {pstats}")
        return stats

# %%
trainer = CRNNTrainer(train_config)
trainer.prepare()
trainer.restore_from_cfg()
trainer.fit(auto_prepare=False)
# Out:
# [Build] num_classes=63
# [Sanity] input: (32, 32, 100, 1) -> logits: (24, 32, 63)
# Model: "crnn_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_11 (Sequential)      │ (None, 1, 24, 512)     │     5,552,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ map_to_seq (Dense)              │ (32, 24, 64)           │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_1 (Bidirectional)        │ (32, 24, 512)          │       657,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_2 (Bidirectional)        │ (32, 24, 512)          │     1,574,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logits (Dense)                  │ (32, 24, 63)           │        32,319 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,850,367 (29.95 MB)
#  Trainable params: 7,848,319 (29.94 MB)
#  Non-trainable params: 2,048 (8.00 KB)
# [Backbone] CNN
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_77 (Conv2D)              │ (None, 32, 100, 64)    │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_77 (ReLU)                 │ (None, 32, 100, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_44 (MaxPooling2D) │ (None, 16, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_78 (Conv2D)              │ (None, 16, 50, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_78 (ReLU)                 │ (None, 16, 50, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_45 (MaxPooling2D) │ (None, 8, 25, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_79 (Conv2D)              │ (None, 8, 25, 256)     │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_79 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_80 (Conv2D)              │ (None, 8, 25, 256)     │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_80 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_46 (MaxPooling2D) │ (None, 4, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_81 (Conv2D)              │ (None, 4, 25, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_81 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_82 (Conv2D)              │ (None, 4, 25, 512)     │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_82 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_47 (MaxPooling2D) │ (None, 2, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_83 (Conv2D)              │ (None, 1, 24, 512)     │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_83 (ReLU)                 │ (None, 1, 24, 512)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,552,896 (21.18 MB)
#  Trainable params: 5,550,848 (21.17 MB)
#  Non-trainable params: 2,048 (8.00 KB)
# [Checkpoint] Restored from latest: checkpoints/ckpt-5000
# [Checkpoint] Resuming from global_step: 5000
#
# ===== Epoch 1 =====
# Evaluate:  75%|███████▌  | 15/20 [06:03<02:01, 24.21s/it]
# [Step 5000] batch loss: 7.1063 | running avg loss: 7.1063
# Evaluate: 100%|██████████| 20/20 [01:21<00:00,  4.10s/it]
# [Eval @ step 5000] {'loss': 5.172192630767822, 'acc': 0.5255, 'wrong_cases': [('INTERROGATOR', 'INTERROCATOY'), ('Multi', 'Miuuler'), ('pissoir', 'Pissoir'), ('25TH', 'PSE'), ('disproofs', 'diswroafs'), ('Mcdaniel', 'Medantel'), ('plowing', 'Plowing'), ('THEREOF', 'THENEOF'), ('Stamen', 'Stamer'), ('PRESUMPTION', 'PAESUMPTHON'), ('lassoed', 'Lassoed'), ('tableware', 'TANLLWARY'), ('BERATED', 'BERFTED'), ('BOOTED', 'BooTeD'), ('smock', 'SMOCK'), ('harmonically', 'harmonieally'), ('passed', 'zussed'), ('JACOBS', 'VACOBS'), ('UPBRAIDED', 'UPERAIDED'), ('kerfuffles', 'Lerfuffles'), ('Hybridism', 'Myiriass'), ('ambassadorway', 'uesudowy'), ('Relinquish', 'Relinguish'), ('UNHURT', 'MTILY'), ('SEMIPRIVATE', 'SEmIPRIWATE'), ('gazillions', 'quiillions'), ('VIBRATES', 'VERATES'), ('PORTRAYING', 'PORTRAVING'), ('legalism', 'tigatiene'), ('Gussying', 'Gussviny'), ('Thrombosis', 'Thrombosts'), ('fillet', 'fiiler'), ('Internalization', 'Intermaization'), ('playoffs', 'Playoffs'), ('Ebert', 'Fbert'), ('DISMISSIVE', 'DISMTSSIvE'), ('Millrace', 'MalbraLe'), ('pasteurizers', 'pacteurtzere'), ('wand', 'wued'), ('redeems', 'redeens'), ('Subcontracting', 'Satentrachng'), ('FURROW', 'Cumoa'), ('Metamorphoses', 'Metamorpheses'), ('PALMETTOS', 'LUMETLOS'), ('GIMPS', 'CIMPS'), ('SUNRISE', 'SUNAISE'), ('RETIREES', 'RETURBES'), ('LANDWARD', 'EaMDWarD'), ('DVISORY', 'DUISORY'), ('CAULKED', 'CAuLKED'), ('Amphibian', 'Anpbibten'), ('Khoisan', 'Knoisan'), ('CHANTILLY', 'CHANTiLLY'), ('Befouled', 'befuuled'), ('saks', 'Saks'), ('DROUGHTS', 'DROUCHTS'), ('NUTRITIONALLY', 'NUTRTIOMALLY'), ('banger', 'bunger'), ('Unseals', 'Keas'), ('HOUSEMAID', 'spupaths'), ('Vic', 'Wic'), ('plautus', 'Plautus'), ('Rekindled', 'Frkirdled'), ('Simple', 'seupe'), ('Benis', 'Jemts'), ('WIN', 'WiN'), ('SAXOPHONISTS', 'SAKOPHONSTS'), ('CASTER', 'CASTEK'), ('FORNICATES', 'FORMICATES'), ('counterfoils', 'Inumterfoils'), ('WAVED', 'WAVE'), ('Fer', 'Fez'), ('Heavers', 'Havers'), ('Nascence', 'Aascence'), ('COINCIDENTALLY', 'CUNCDENTALLY'), ('Enmeshment', 'Emecheont'), ('hammers', 'Lammees'), ('delouse', 'detoers'), ('fromm', 'frorm'), ('Toweling', 'Toeting'), ('Events', 'Evenrs'), ('repose', 'ePuSe'), ('waco', 'wac'), ('BLUFFNESS', 'CLUNNIeS'), ('garrulous', 'CAPTuLOLS'), ('Zappy', 'Lappy'), ('Bulldogging', 'Buldogging'), ('Gyve', 'Ewve'), ('refractory', 'nstaty'), ('CONJUNCTIONS', 'COYUNCTIONS'), ('CHARRED', 'ChArked'), ('CRUDE', 'CRUDS'), ('JURIST', 'JuriSt'), ('Trapeziums', 'Irapezums'), ('DINH', 'DIMH'), ('radiotelegraphs', 'rontiotelegrayhs'), ('SUBSTITUTIONS', 'Suestrutions'), ('Uppers', 'LITTekS'), ('REPROACHABLE', 'MRONCHABLS'), ('Riderless', 'Rilerless'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'NONEELUGERENT'), ('bargeman', 'bargemen'), ('GADOLINIUM', 'CABOLINUN'), ('Guayaquil', 'Outyaguil'), ('PAPERHANGING', 'PAPERMANGING'), ('consolidated', 'conretiiates'), ('Chivas', 'Chiues'), ('DEFACED', 'DEKACED'), ('Deportee', 'peportes'), ('vogue', 'voque'), ('Stupendously', 'styubously'), ('comdr', 'condr'), ('Motorcyclist', 'MOTORCYCLIST'), ('GREENWICH', 'CREENWICH'), ('joyous', 'jevous'), ('plow', 'Plow'), ('colorful', 'coloral'), ('Gymnasts', 'qumests'), ('PULLOUT', 'PULLOuT'), ('frontally', 'FRONTALLY'), ('stanza', 'Stanza'), ('Geezers', 'Ceezers'), ('Pvt', 'Faut'), ('MACARONI', 'MACARON'), ('INDIGENCE', 'ENDHCENCS'), ('Mocha', 'MOCHa'), ('HOMEOPATHIC', 'MONCOTATHIC'), ('FISHER', 'FISMER'), ('Hus', 'SiS'), ('ARMLOADS', 'ARmLOADS'), ('PERISTALTIC', 'PHRISTALTIC'), ('Veronese', 'Wenonene'), ('illustration', 'ilutctiow'), ('Racks', 'RACKS'), ('PALMOLIVE', 'PHLMGLWS'), ('SEDUCTIVELY', 'SEDuCTIVELY'), ('Sedate', 'Sedute'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLENINS'), ('Clare', 'Clarre'), ('UNIONIZED', 'WntOnzED'), ('delicatessen', 'delicotessen'), ('cantering', 'Cantering'), ('HYPOTHETICALLY', 'HYPOTHETICALY'), ('REPHRASES', 'REPHrASES'), ('mosley', 'as'), ('GELCAP', 'Geiap'), ('TOKING', 'TOXING'), ('Bent', 'Bevt'), ('BARGEMEN', 'LAKEEmEN'), ('BREXTON', 'BrEKTON'), ('BLUFFER' ...
# [Checkpoint] Saved: checkpoints/ckpt-5000 (global_step: 5000)
# [Checkpoint] H5 weights saved: checkpoints/model_005000.weights.h5
# [Step 5010] batch loss: 4.2577 | running avg loss: 5.0352
# [Step 5020] batch loss: 4.7531 | running avg loss: 5.2059
# [Step 5030] batch loss: 4.3546 | running avg loss: 5.0672
# [Step 5040] batch loss: 5.4840 | running avg loss: 5.0724
# [Step 5050] batch loss: 2.6287 | running avg loss: 4.8642
# [Step 5060] batch loss: 4.5810 | running avg loss: 4.8376
# [Step 5070] batch loss: 3.7359 | running avg loss: 4.8861
# [Step 5080] batch loss: 4.1370 | running avg loss: 4.9228
# [Step 5090] batch loss: 6.1444 | running avg loss: 4.9209
# [Step 5100] batch loss: 5.9204 | running avg loss: 4.9322
# [Step 5110] batch loss: 6.0214 | running avg loss: 4.8700
# [Step 5120] batch loss: 3.0250 | running avg loss: 4.8065
# [Step 5130] batch loss: 6.1257 | running avg loss: 4.8396
# [Step 5140] batch loss: 5.5188 | running avg loss: 4.8444
# [Step 5150] batch loss: 7.0110 | running avg loss: 4.8578
# [Step 5160] batch loss: 7.9258 | running avg loss: 4.8773
# [Step 5170] batch loss: 4.1263 | running avg loss: 4.8869
# [Step 5180] batch loss: 3.9612 | running avg loss: 4.8325
# [Step 5190] batch loss: 5.8297 | running avg loss: 4.8318
# [Step 5200] batch loss: 5.1451 | running avg loss: 4.8189
# [Step 5210] batch loss: 4.0390 | running avg loss: 4.8429
# [Step 5220] batch loss: 3.1521 | running avg loss: 4.7971
# [Step 5230] batch loss: 1.7265 | running avg loss: 4.7609
# [Step 5240] batch loss: 4.1149 | running avg loss: 4.7488
# [Step 5250] batch loss: 3.4056 | running avg loss: 4.7317
# [Step 5260] batch loss: 4.1018 | running avg loss: 4.7376
# [Step 5270] batch loss: 6.3681 | running avg loss: 4.7214
# [Step 5280] batch loss: 4.7656 | running avg loss: 4.7262
# [Step 5290] batch loss: 7.2115 | running avg loss: 4.7236
# [Step 5300] batch loss: 4.5869 | running avg loss: 4.7563
# [Step 5310] batch loss: 4.9072 | running avg loss: 4.7505
# [Step 5320] batch loss: 5.8205 | running avg loss: 4.7616
# [Step 5330] batch loss: 7.0223 | running avg loss: 4.7483
# [Step 5340] batch loss: 3.7785 | running avg loss: 4.7207
# [Step 5350] batch loss: 2.4598 | running avg loss: 4.7130
# [Step 5360] batch loss: 5.2123 | running avg loss: 4.7094
# [Step 5370] batch loss: 3.4222 | running avg loss: 4.7023
# [Step 5380] batch loss: 4.8915 | running avg loss: 4.7036
# [Step 5390] batch loss: 3.3330 | running avg loss: 4.7172
# [Step 5400] batch loss: 3.9756 | running avg loss: 4.7181
# [Step 5410] batch loss: 4.5733 | running avg loss: 4.7093
# [Step 5420] batch loss: 3.4604 | running avg loss: 4.6951
# [Step 5430] batch loss: 3.6321 | running avg loss: 4.6795
# [Step 5440] batch loss: 2.7482 | running avg loss: 4.6592
# [Step 5450] batch loss: 2.2763 | running avg loss: 4.6505
# [Step 5460] batch loss: 6.5431 | running avg loss: 4.6421
# [Step 5470] batch loss: 5.1861 | running avg loss: 4.6526
# [Step 5480] batch loss: 6.4194 | running avg loss: 4.6486
# [Step 5490] batch loss: 5.0629 | running avg loss: 4.6402
# [Step 5500] batch loss: 2.2780 | running avg loss: 4.6274
# Evaluate: 100%|██████████| 20/20 [01:21<00:00,  4.10s/it]
# [Eval @ step 5500] {'loss': 4.864372613525391, 'acc': 0.5656, 'wrong_cases': [('INTERROGATOR', 'INTERROCATOP'), ('Multi', 'Niuler'), ('25TH', 'DSTEL'), ('Mcdaniel', 'Modantel'), ('plowing', 'Plowing'), ('THEREOF', 'THENEOE'), ('Palpable', 'Pelpable'), ('PRESUMPTION', 'PRESUNPTHON'), ('lassoed', 'Lassoed'), ('Vazquez', 'Vazquer'), ('tableware', 'TARLSVArY'), ('BERATED', 'BERFITED'), ('smock', 'SMOCK'), ('harmonically', 'harmonially'), ('UPBRAIDED', 'UPERAIDED'), ('kerfuffles', 'lerfrffles'), ('Hybridism', 'MyDriaiSD'), ('ambassadorway', 'ULRaLovEY'), ('UNHURT', 'UENINY'), ('SEMIPRIVATE', 'SEIMIPRIVATE'), ('gazillions', 'padillions'), ('VIBRATES', 'VERATES'), ('TANTALIZERS', 'INNITALIZERS'), ('napoleonic', 'mapoleonic'), ('legalism', 'tegaliene'), ('Gussying', 'Guassviny'), ('Thrombosis', 'Thrombosts'), ('fillet', 'fiiler'), ('Internalization', 'Interalitation'), ('Penuche', 'Denuche'), ('Ebert', 'Fbert'), ('DISMISSIVE', 'DiSMTISSTVE'), ('Millrace', 'WAOUrALe'), ('pasteurizers', 'pacteurizers'), ('wand', 'PY'), ('almshouse', 'aimshouse'), ('Subcontracting', 'Saleantraching'), ('FURROW', 'CUFROD'), ('Metamorphoses', 'Metemoroloses'), ('PALMETTOS', 'LANLENBOS'), ('HAZINGS', 'MAZINGS'), ('km', 'kmn'), ('RETIREES', 'RETURBES'), ('LANDWARD', 'HANDWARD'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Amohibien'), ('CHANTILLY', 'CHANTOLILY'), ('Pixel', 'pixel'), ('NUTRITIONALLY', 'MOPRIPIONALLY'), ('Noninflected', 'Noninilected'), ('MOVEMENTS', 'MOVEMEATS'), ('Unseals', 'Raes'), ('HOUSEMAID', 'Toudetae'), ('Rekindled', 'Frlindled'), ('Simple', 'Mimpte'), ('Benis', 'Siemis'), ('SAXOPHONISTS', 'SAKOPHONSTS'), ('counterfoils', 'Unpterfoils'), ('COINCIDENTALLY', 'CONCIDENTALLY'), ('Enmeshment', 'Enmeshaont'), ('hammers', 'dammiey'), ('delouse', 'delosrs'), ('Windows', 'Wincows'), ('fromm', 'fromn'), ('Toweling', 'Tomoling'), ('Events', 'Suers'), ('repose', 'repmse'), ('waco', 'wac'), ('BLUFFNESS', 'DLUFPNNES'), ('Steadfast', 'steadfast'), ('garrulous', 'CAPRLOLS'), ('Zappy', 'Lappy'), ('Gyve', 'Crve'), ('refractory', 'Aagtaly'), ('CHARRED', 'CHANRED'), ('CRUDE', 'CROOS'), ('WARHOL', 'WARAIOL'), ('Trapeziums', 'Traperiums'), ('radiotelegraphs', 'ratiotetgraphs'), ('SUBSTITUTIONS', 'SussTIruroNs'), ('Uppers', 'LpperS'), ('REPROACHABLE', 'MRONCHABLE'), ('Riderless', 'Cilerless'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'IONBELUIGERENT'), ('bargeman', 'bergeen'), ('GADOLINIUM', 'GADOLINIUN'), ('Guayaquil', 'Ousyagniy'), ('PAPERHANGING', 'PAPERMANGING'), ('consolidated', 'comvetidated'), ('Chivas', 'Chrves'), ('Fleshlier', 'Rleshlier'), ('Stupendously', 'Sipuslonsly'), ('comdr', 'condr'), ('Motorcyclist', 'MOTORCYOLIST'), ('GREENWICH', 'GREENTWICH'), ('colorful', 'ColorTeN'), ('uhd', 'und'), ('Gymnasts', 'gmmasts'), ('frontally', 'FRONTALLY'), ('stanza', 'Stamza'), ('Pvt', 'Fart'), ('ocher', 'Ocher'), ('MACARONI', 'MACARONT'), ('ANTICIPATES', 'ANTIGIPATES'), ('INDIGENCE', 'ENDICENCE'), ('Mocha', 'MOCHa'), ('HOMEOPATHIC', 'IONCOPATHIG'), ('FISHER', 'FISWSR'), ('Hus', 'es'), ('coding', 'cocling'), ('Evoke', 'EYOKE'), ('PERISTALTIC', 'PERISTALTIG'), ('Veronese', 'Uenonele'), ('illustration', 'Hlutctior'), ('Racks', 'RACIES'), ('PALMOLIVE', 'PRUMOLIDS'), ('SEDUCTIVELY', 'SEDUGTIVELY'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLONITES'), ('Clare', 'Glalre'), ('UNIONIZED', 'UNIONIRED'), ('delicatessen', 'delicotessen'), ('cantering', 'Cantering'), ('HYPOTHETICALLY', 'HYPOTHETICALY'), ('ELIAS', 'FLIAS'), ('mosley', 'P'), ('GELCAP', 'GEICAP'), ('TOKING', 'TOHING'), ('Bent', 'Bert'), ('BARGEMEN', 'BAREGINIGN'), ('BREXTON', 'BREkTON'), ('BLUFFER', 'RUIPPE'), ('blanking', 'BLANIKING'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Prommbbing'), ('salvadorians', 'prares'), ('SLANGIER', 'GAANUNEN'), ('Knight', 'Kiigh'), ('Recirculated', 'CET'), ('Sandblast', 'Sardllast'), ('Xiaoping', 'Kiaoping'), ('blackthorns', 'blackthoms'), ('Oft', 'F'), ('122', 'I2P'), ('layered', 'Cayerpd'), ('cayenne', 'cayenns'), ('GRANULATES', 'ERNIGLNES'), ('Janie', 'Jane'), ('Hodge', 'Ho ...
# [Checkpoint] Saved: checkpoints/ckpt-5500 (global_step: 5500)
# [Checkpoint] H5 weights saved: checkpoints/model_005500.weights.h5
# [Step 5510] batch loss: 4.1799 | running avg loss: 4.6312
# [Step 5520] batch loss: 4.9982 | running avg loss: 4.6341
# [Step 5530] batch loss: 8.9638 | running avg loss: 4.6479
# [Step 5540] batch loss: 6.4071 | running avg loss: 4.6504
# [Step 5550] batch loss: 5.2697 | running avg loss: 4.6565
# [Step 5560] batch loss: 4.0618 | running avg loss: 4.6639
# [Step 5570] batch loss: 3.3176 | running avg loss: 4.6610
# [Step 5580] batch loss: 4.4758 | running avg loss: 4.6682
# [Step 5590] batch loss: 6.2976 | running avg loss: 4.6660
# [Step 5600] batch loss: 2.9327 | running avg loss: 4.6684
# [Step 5610] batch loss: 7.4732 | running avg loss: 4.6668
# [Step 5620] batch loss: 5.6852 | running avg loss: 4.6785
# [Step 5630] batch loss: 2.4837 | running avg loss: 4.6742
# [Step 5640] batch loss: 6.7833 | running avg loss: 4.6823
# [Step 5650] batch loss: 5.9873 | running avg loss: 4.6756
# [Step 5660] batch loss: 4.9227 | running avg loss: 4.6790
# [Step 5670] batch loss: 6.2132 | running avg loss: 4.6848
# [Step 5680] batch loss: 5.9870 | running avg loss: 4.6719
# [Step 5690] batch loss: 3.2956 | running avg loss: 4.6758
# [Step 5700] batch loss: 3.9081 | running avg loss: 4.6695
# [Step 5710] batch loss: 4.0809 | running avg loss: 4.6764
# [Step 5720] batch loss: 2.8027 | running avg loss: 4.6698
# [Step 5730] batch loss: 5.7131 | running avg loss: 4.6646
# [Step 5740] batch loss: 3.3573 | running avg loss: 4.6605
# [Step 5750] batch loss: 4.1348 | running avg loss: 4.6631
# [Step 5760] batch loss: 4.1100 | running avg loss: 4.6537
# [Step 5770] batch loss: 4.7651 | running avg loss: 4.6441
# [Step 5780] batch loss: 5.3334 | running avg loss: 4.6382
# [Step 5790] batch loss: 4.4866 | running avg loss: 4.6387
# [Step 5800] batch loss: 4.1520 | running avg loss: 4.6451
# [Step 5810] batch loss: 2.6940 | running avg loss: 4.6358
# [Step 5820] batch loss: 2.8217 | running avg loss: 4.6391
# [Step 5830] batch loss: 7.6604 | running avg loss: 4.6495
# [Step 5840] batch loss: 6.0804 | running avg loss: 4.6532
# [Step 5850] batch loss: 6.2998 | running avg loss: 4.6622
# [Step 5860] batch loss: 6.3121 | running avg loss: 4.6699
# [Step 5870] batch loss: 2.0146 | running avg loss: 4.6670
# [Step 5880] batch loss: 3.4521 | running avg loss: 4.6644
# [Step 5890] batch loss: 3.2481 | running avg loss: 4.6628
# [Step 5900] batch loss: 3.4650 | running avg loss: 4.6677
# [Step 5910] batch loss: 3.1629 | running avg loss: 4.6643
# [Step 5920] batch loss: 3.2845 | running avg loss: 4.6509
# [Step 5930] batch loss: 4.7433 | running avg loss: 4.6503
# [Step 5940] batch loss: 2.5697 | running avg loss: 4.6431
# [Step 5950] batch loss: 3.6445 | running avg loss: 4.6429
# [Step 5960] batch loss: 2.9706 | running avg loss: 4.6336
# [Step 5970] batch loss: 3.8769 | running avg loss: 4.6239
# [Step 5980] batch loss: 2.2376 | running avg loss: 4.6232
# [Step 5990] batch loss: 5.0309 | running avg loss: 4.6245
# [Step 6000] batch loss: 5.2806 | running avg loss: 4.6232
# Evaluate: 100%|██████████| 20/20 [01:11<00:00,  3.56s/it]
# [Eval @ step 6000] {'loss': 4.67182710647583, 'acc': 0.5669, 'wrong_cases': [('INTERROGATOR', 'INTERROGAION'), ('Multi', 'Muktt'), ('25TH', 'BSTE'), ('Mcdaniel', 'Modaniel'), ('plowing', 'Plowing'), ('THEREOF', 'THEREOT'), ('tableware', 'TABLSYARS'), ('BOOTED', 'BOOTeD'), ('smock', 'SMOCK'), ('harmonically', 'harmonieally'), ('passed', 'zassed'), ('JACOBS', 'JacoBs'), ('kerfuffles', 'ferfuffles'), ('Hybridism', 'Hybpidiss'), ('ambassadorway', 'absneudorg'), ('Relinquish', 'Relinguish'), ('UNHURT', 'LNLY'), ('gazillions', 'gagillions'), ('VIBRATES', 'VBRATES'), ('TANTALIZERS', 'TAMDALIZERS'), ('legalism', 'tagahisns'), ('Gussying', 'Gusszing'), ('ISUZU', 'ISUZ'), ('MISSTEPS', 'MISSTepS'), ('Thrombosis', 'Thrombosls'), ('fillet', 'filler'), ('Internalization', 'Internaliation'), ('Penuche', 'Benuche'), ('DISMISSIVE', 'DISISSIYE'), ('Millrace', 'Hsbirbbs'), ('wand', 'ccey'), ('redeems', 'redeens'), ('Subcontracting', 'Sobemtraching'), ('FURROW', 'Cuno'), ('Metamorphoses', 'Metamorphoss'), ('PALMETTOS', 'kMEnBOs'), ('SUNRISE', 'SUNAISE'), ('RETIREES', 'RETURBES'), ('LANDWARD', 'EaNDWarD'), ('DVISORY', 'DUISORY'), ('convoke', 'Convoke'), ('Amphibian', 'Amphibion'), ('Khoisan', 'Knoisan'), ('Cupcake', 'Gupcake'), ('NUTRITIONALLY', 'NUFRIFINALLY'), ('Noninflected', 'Noniniected'), ('Maharashtra', 'Haharashtra'), ('INVEIGLE', 'INEIGLE'), ('banger', 'bunger'), ('Unseals', 'Kaads'), ('HOUSEMAID', 'RoUDaNs'), ('Rekindled', 'Frkindled'), ('Simple', 'Sonble'), ('Benis', 'Semis'), ('SAXOPHONISTS', 'SAXOPHONSTS'), ('FORNICATES', 'FORNIGATES'), ('counterfoils', 'tountenfoils'), ('reediest', 'Teediest'), ('Fer', 'fet'), ('Heavers', 'Heavets'), ('Nascence', 'Mascence'), ('COINCIDENTALLY', 'CINCDENTALLY'), ('Enmeshment', 'Enmeshoont'), ('hammers', 'daminels'), ('delouse', 'deboase'), ('circumcised', 'circumncised'), ('Windows', 'Wincows'), ('Toweling', 'Towcling'), ('Events', 'Bvents'), ('repose', 'repnst'), ('waco', 'Uao'), ('BLUFFNESS', 'CLUTNISS'), ('overturned', 'overtarned'), ('garrulous', 'GARRLOLS'), ('Zappy', 'Lappy'), ('Gyve', 'CawVe'), ('refractory', 'Magbaly'), ('CONJUNCTIONS', 'CONSUNCTIORS'), ('CRUDE', 'CRNDG'), ('JURIST', 'JUrist'), ('Trapeziums', 'Irapeziuns'), ('radiotelegraphs', 'ratiotebgraphs'), ('SUBSTITUTIONS', 'Suestrurions'), ('Uppers', 'Urreks'), ('stronger', 'Stronger'), ('CHURCHILL', 'CHURCHLL'), ('REPROACHABLE', 'MRONCHABLS'), ('Sledding', 'Sjedding'), ('starched', 'Starched'), ('NONBELLIGERENT', 'MONBELIGERENT'), ('bargeman', 'bargemen'), ('GADOLINIUM', 'GADOLIMIUM'), ('Guayaquil', 'Gufyhguil'), ('consolidated', 'comrotidated'), ('loathsome', 'boathsome'), ('DEFACED', 'DErACED'), ('Deportee', 'Deportes'), ('Fleshlier', 'Rleshlier'), ('vogue', 'voque'), ('Stupendously', 'Snpeubously'), ('Inexpert', 'hnexpert'), ('comdr', 'Comdr'), ('Motorcyclist', 'Motorcrolist'), ('GREENWICH', 'GREENWIC'), ('joyous', 'jayous'), ('colorful', 'Colorial'), ('Gymnasts', 'Gmnasts'), ('LUNCHEON', 'LUNGHEON'), ('frontally', 'FRONTALLY'), ('stanza', 'Stanza'), ('Pvt', 'Eautt'), ('ANTICIPATES', 'ANTIGIPATES'), ('INDIGENCE', 'ENDIGENCS'), ('HOMEOPATHIC', 'IONCOTATHIC'), ('FISHER', 'FISMSR'), ('EIDERDOWNS', 'BIDERDOWNS'), ('Hus', 'lS'), ('CONVERSION', 'COnVeRSioN'), ('Evoke', 'EYokE'), ('Veronese', 'Uenonhele'), ('illustration', 'dstchiog'), ('HYSTERIC', 'HYSTERC'), ('Racks', 'RACKS'), ('PALMOLIVE', 'PALMOLANS'), ('SEDUCTIVELY', 'SEDUGTIVELY'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLONTS'), ('Clare', 'Glalre'), ('UNIONIZED', 'UMICNILED'), ('delicatessen', 'delicotessen'), ('HYPOTHETICALLY', 'EYPOTHETICALY'), ('ELIAS', 'ELAS'), ('mosley', 'Cs'), ('GELCAP', 'Getgap'), ('TOKING', 'TOMING'), ('Bent', 'Bert'), ('BARGEMEN', 'BARBENEN'), ('BREXTON', 'BBERTON'), ('BLUFFER', 'AGTE'), ('blanking', 'BLANKING'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Proonbbing'), ('salvadorians', 'Botares'), ('SLANGIER', 'CANNGRER'), ('Knight', 'Knigh'), ('Recirculated', 'Cog'), ('Xiaoping', 'xiaoping'), ('blackthorns', 'blackthoms'), ('Oft', 'fl'), ('122', '12e'), ...
# [Checkpoint] Saved: checkpoints/ckpt-6000 (global_step: 6000)
# [Checkpoint] H5 weights saved: checkpoints/model_006000.weights.h5
# [Step 6010] batch loss: 2.9337 | running avg loss: 4.6168
# [Step 6020] batch loss: 3.8380 | running avg loss: 4.6155
# [Step 6030] batch loss: 3.9954 | running avg loss: 4.6169
# [Step 6040] batch loss: 5.4116 | running avg loss: 4.6162
# [Step 6050] batch loss: 6.9070 | running avg loss: 4.6124
# [Step 6060] batch loss: 5.2958 | running avg loss: 4.6140
# [Step 6070] batch loss: 5.2664 | running avg loss: 4.6136
# [Step 6080] batch loss: 3.6251 | running avg loss: 4.6071
# [Step 6090] batch loss: 4.0199 | running avg loss: 4.6002
# [Step 6100] batch loss: 3.0935 | running avg loss: 4.5992
# [Step 6110] batch loss: 5.9844 | running avg loss: 4.5972
# [Step 6120] batch loss: 4.8171 | running avg loss: 4.6040
# [Step 6130] batch loss: 3.0546 | running avg loss: 4.6005
# [Step 6140] batch loss: 3.9812 | running avg loss: 4.6023
# [Step 6150] batch loss: 4.8481 | running avg loss: 4.6003
# [Step 6160] batch loss: 4.0856 | running avg loss: 4.5946
# [Step 6170] batch loss: 2.8369 | running avg loss: 4.5936
# [Step 6180] batch loss: 6.1281 | running avg loss: 4.5904
# [Step 6190] batch loss: 5.5531 | running avg loss: 4.5915
# [Step 6200] batch loss: 3.3628 | running avg loss: 4.5931
# [Step 6210] batch loss: 1.7559 | running avg loss: 4.5837
# [Step 6220] batch loss: 4.2371 | running avg loss: 4.5855
# [Step 6230] batch loss: 2.3226 | running avg loss: 4.5739
# [Step 6240] batch loss: 5.5990 | running avg loss: 4.5784
# [Step 6250] batch loss: 3.5508 | running avg loss: 4.5730
# [Step 6260] batch loss: 2.8001 | running avg loss: 4.5676
# [Step 6270] batch loss: 4.0012 | running avg loss: 4.5690
# [Step 6280] batch loss: 5.6523 | running avg loss: 4.5630
# [Step 6290] batch loss: 4.6061 | running avg loss: 4.5567
# [Step 6300] batch loss: 2.9540 | running avg loss: 4.5585
# [Step 6310] batch loss: 3.1141 | running avg loss: 4.5568
# [Step 6320] batch loss: 2.8554 | running avg loss: 4.5494
# [Step 6330] batch loss: 5.5204 | running avg loss: 4.5531
# [Step 6340] batch loss: 6.4361 | running avg loss: 4.5504
# [Step 6350] batch loss: 4.4840 | running avg loss: 4.5487
# [Step 6360] batch loss: 3.9496 | running avg loss: 4.5492
# [Step 6370] batch loss: 6.1395 | running avg loss: 4.5485
# [Step 6380] batch loss: 3.6049 | running avg loss: 4.5500
# [Step 6390] batch loss: 6.0507 | running avg loss: 4.5452
# [Step 6400] batch loss: 5.1701 | running avg loss: 4.5453
# [Step 6410] batch loss: 4.6807 | running avg loss: 4.5446
# [Step 6420] batch loss: 3.5179 | running avg loss: 4.5377
# [Step 6430] batch loss: 2.1350 | running avg loss: 4.5336
# [Step 6440] batch loss: 5.3241 | running avg loss: 4.5259
# [Step 6450] batch loss: 7.5392 | running avg loss: 4.5255
# [Step 6460] batch loss: 5.2887 | running avg loss: 4.5213
# [Step 6470] batch loss: 3.1306 | running avg loss: 4.5170
# [Step 6480] batch loss: 3.3023 | running avg loss: 4.5101
# [Step 6490] batch loss: 3.2577 | running avg loss: 4.5066
# [Step 6500] batch loss: 4.2387 | running avg loss: 4.5080
# Evaluate: 100%|██████████| 20/20 [01:05<00:00,  3.29s/it]
# [Eval @ step 6500] {'loss': 4.650373094940186, 'acc': 0.5722, 'wrong_cases': [('INTERROGATOR', 'INTERROGATON'), ('Multi', 'sukt'), ('25TH', 'aSIE'), ('Mcdaniel', 'Modanial'), ('plowing', 'Plowing'), ('THEREOF', 'THENEOF'), ('Stamen', 'Stamenn'), ('PRESUMPTION', 'FNESUMTTHON'), ('tableware', 'TABLsYArS'), ('Cobwebby', 'cobwebby'), ('BOOTED', 'BooTed'), ('smock', 'SMOCK'), ('thinness', 'tninness'), ('passed', 'passeL'), ('kerfuffles', 'Lerfuffles'), ('Dvd', 'Ivd'), ('Hybridism', 'Mybriaism'), ('ambassadorway', 'cnlenudorer'), ('Relinquish', 'Relinguish'), ('UNHURT', 'WENUAS'), ('SEMIPRIVATE', 'SEMUIPRIVATE'), ('gazillions', 'pusillions'), ('VIBRATES', 'VBRATIES'), ('TANTALIZERS', 'TAMTALIZERS'), ('legalism', 'lagalism'), ('fillet', 'filler'), ('Internalization', 'Intermelization'), ('Ebert', 'Fbert'), ('Millrace', 'Msdirabe'), ('pasteurizers', 'pastousizere'), ('wand', 'aued'), ('almshouse', 'slmshouse'), ('redeems', 'redeenas'), ('Subcontracting', 'Suleantrachng'), ('FURROW', 'RUnnous'), ('Metamorphoses', 'Metamorohoses'), ('PALMETTOS', 'LAMEnnNs'), ('RETIREES', 'IRETURBES'), ('LANDWARD', 'LANDWaRD'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Amahibion'), ('Khoisan', 'Knoisan'), ('CHANTILLY', 'CHASTULLY'), ('Befouled', 'Eefouled'), ('Cupcake', 'Gupcake'), ('Pixel', 'pixel'), ('NUTRITIONALLY', 'NOTRITIOMALLY'), ('Noninflected', 'Noninfiacted'), ('banger', 'bunger'), ('Unseals', 'Aaacs'), ('HOUSEMAID', 'rousuiss'), ('Rekindled', 'Frlindled'), ('Simple', 'Muhte'), ('Benis', 'Jaemis'), ('SAXOPHONISTS', 'SAXOPHONSTS'), ('FORNICATES', 'FORNIGATES'), ('counterfoils', 'Imnterfails'), ('antidote', 'untidote'), ('COINCIDENTALLY', 'OUNCDENTALLY'), ('Enmeshment', 'Ermashasnt'), ('hammers', 'dammsss'), ('delouse', 'dulouse'), ('circumcised', 'dircumgised'), ('Windows', 'Windowys'), ('Toweling', 'Toueling'), ('Ploy', 'ploy'), ('repose', 'repise'), ('waco', 'wabe'), ('BLUFFNESS', 'BLUFTNEIES'), ('garrulous', 'CATULOUS'), ('Zappy', 'Lappy'), ('Gyve', 'Canve'), ('refractory', 'siaghay'), ('CONJUNCTIONS', 'CONYUINCTIONS'), ('CHARRED', 'CHANRED'), ('CRUDE', 'GRUDS'), ('DINH', 'DIWH'), ('radiotelegraphs', 'radiolcugraphs'), ('SUBSTITUTIONS', 'SUsSTITuTions'), ('Uppers', 'UrprS'), ('REPROACHABLE', 'UPROACHABLE'), ('Riderless', 'Rilerless'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'NONBELUGERENT'), ('bargeman', 'bargaman'), ('GADOLINIUM', 'GAOOLIMIUM'), ('Guayaquil', 'Gusyaguiy'), ('consolidated', 'consotidated'), ('Chivas', 'Ghivas'), ('Deportee', 'peportee'), ('Fleshlier', 'Feshlier'), ('Stupendously', 'Srguabously'), ('Motorcyclist', 'MOTORGYGLIST'), ('GREENWICH', 'GREENWIGH'), ('colorful', 'coloral'), ('Gymnasts', 'gymmasts'), ('frontally', 'FRONITALLY'), ('OCTAVIA', 'OCTAVLA'), ('Geezers', 'Ceezers'), ('Pvt', 'Baut'), ('MACARONI', 'MACARONT'), ('ANTICIPATES', 'ANTIGIPATES'), ('INDIGENCE', 'ENDIGENCE'), ('Mocha', 'MOCHa'), ('strolling', 'sirolling'), ('HOMEOPATHIC', 'SOMTOTATHIG'), ('FISHER', 'FUSMSR'), ('Hus', 'Bas'), ('Evoke', 'EYOKE'), ('Veronese', 'Uenonese'), ('illustration', 'isctios'), ('Racks', 'RACILS'), ('PALMOLIVE', 'PALMGLUS'), ('SEDUCTIVELY', 'SeDugtively'), ('Sedate', 'Jedate'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLONINY'), ('Clare', 'Glalre'), ('UNIONIZED', 'UMIonIAED'), ('delicatessen', 'delicotessen'), ('HYPOTHETICALLY', 'EYPOTHETICALY'), ('REPHRASES', 'REPHrASES'), ('mosley', 'Bd'), ('GELCAP', 'GErGAP'), ('TOKING', 'TOMING'), ('BARGEMEN', 'MARGEMEN'), ('BREXTON', 'BEEXtOn'), ('BLUFFER', 'ALUAPEN'), ('blanking', 'BLANKING'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Preambbing'), ('salvadorians', 'ptures'), ('SLANGIER', 'GANNUSEN'), ('Knight', 'Knigm'), ('Recirculated', 'cior'), ('Xiaoping', 'xiaoping'), ('blackthorns', 'blackthoms'), ('premium', 'premjum'), ('Oft', 'fy'), ('122', '1ee'), ('layered', 'layesed'), ('GRANULATES', 'ERANIULNES'), ('OGLING', 'OGHING'), ('Kingly', 'Kusueshy'), ('Evocatively', 'Gunendunly'), ('CHEST', 'ChEST'), ('Bedazzlement', 'Berdoualement'), ('stereotyped', 'stereotyned'), ('WADDLED', 'ILADDLED ...
# [Checkpoint] Saved: checkpoints/ckpt-6500 (global_step: 6500)
# [Checkpoint] H5 weights saved: checkpoints/model_006500.weights.h5
# [Step 6510] batch loss: 3.5247 | running avg loss: 4.5052
# [Step 6520] batch loss: 4.9302 | running avg loss: 4.5077
# [Step 6530] batch loss: 6.2727 | running avg loss: 4.5143
# [Step 6540] batch loss: 2.4640 | running avg loss: 4.5137
# [Step 6550] batch loss: 3.0699 | running avg loss: 4.5090
# [Step 6560] batch loss: 3.7683 | running avg loss: 4.5075
# [Step 6570] batch loss: 5.0093 | running avg loss: 4.5070
# [Step 6580] batch loss: 5.5154 | running avg loss: 4.5027
# [Step 6590] batch loss: 4.8054 | running avg loss: 4.5002
# [Step 6600] batch loss: 6.0949 | running avg loss: 4.4985
# [Step 6610] batch loss: 6.3495 | running avg loss: 4.4951
# [Step 6620] batch loss: 4.6805 | running avg loss: 4.4940
# [Step 6630] batch loss: 5.9390 | running avg loss: 4.4924
# [Step 6640] batch loss: 1.6670 | running avg loss: 4.4940
# [Step 6650] batch loss: 2.7605 | running avg loss: 4.4943
# [Step 6660] batch loss: 5.0685 | running avg loss: 4.4944
# [Step 6670] batch loss: 2.9514 | running avg loss: 4.4907
# [Step 6680] batch loss: 5.4076 | running avg loss: 4.4894
# [Step 6690] batch loss: 4.8662 | running avg loss: 4.4841
# [Step 6700] batch loss: 4.8384 | running avg loss: 4.4848
# [Step 6710] batch loss: 2.8598 | running avg loss: 4.4874
# [Step 6720] batch loss: 6.3295 | running avg loss: 4.4881
# [Step 6730] batch loss: 5.7061 | running avg loss: 4.4856
# [Step 6740] batch loss: 3.2763 | running avg loss: 4.4866
# [Step 6750] batch loss: 4.8937 | running avg loss: 4.4847
# [Step 6760] batch loss: 3.6879 | running avg loss: 4.4858
# [Step 6770] batch loss: 2.4277 | running avg loss: 4.4869
# [Step 6780] batch loss: 4.2641 | running avg loss: 4.4871
# [Step 6790] batch loss: 4.9966 | running avg loss: 4.4871
# [Step 6800] batch loss: 5.4821 | running avg loss: 4.4859
# [Step 6810] batch loss: 7.0039 | running avg loss: 4.4871
# [Step 6820] batch loss: 2.6506 | running avg loss: 4.4827
# [Step 6830] batch loss: 4.0664 | running avg loss: 4.4808
# [Step 6840] batch loss: 4.0298 | running avg loss: 4.4754
# [Step 6850] batch loss: 3.4355 | running avg loss: 4.4749
# [Step 6860] batch loss: 5.1431 | running avg loss: 4.4707
# [Step 6870] batch loss: 2.4676 | running avg loss: 4.4680
# [Step 6880] batch loss: 3.3726 | running avg loss: 4.4678
# [Step 6890] batch loss: 5.3375 | running avg loss: 4.4684
# [Step 6900] batch loss: 3.1399 | running avg loss: 4.4644
# [Step 6910] batch loss: 3.9478 | running avg loss: 4.4619
# [Step 6920] batch loss: 6.2280 | running avg loss: 4.4593
# [Step 6930] batch loss: 3.8994 | running avg loss: 4.4591
# [Step 6940] batch loss: 4.9815 | running avg loss: 4.4555
# [Step 6950] batch loss: 2.9088 | running avg loss: 4.4548
# [Step 6960] batch loss: 2.4617 | running avg loss: 4.4538
# [Step 6970] batch loss: 5.3998 | running avg loss: 4.4533
# [Step 6980] batch loss: 4.0846 | running avg loss: 4.4531
# [Step 6990] batch loss: 3.9908 | running avg loss: 4.4503
# [Step 7000] batch loss: 2.8495 | running avg loss: 4.4479
# Evaluate: 100%|██████████| 20/20 [01:04<00:00,  3.24s/it]
# [Eval @ step 7000] {'loss': 4.637065321350097, 'acc': 0.5672, 'wrong_cases': [('INTERROGATOR', 'INTERROGATON'), ('Multi', 'Niuket'), ('25TH', 'OSH'), ('disproofs', 'Aisproofs'), ('Mcdaniel', 'Modantal'), ('plowing', 'Plowing'), ('THEREOF', 'THEREDE'), ('PRESUMPTION', 'FRESUMPTHON'), ('tableware', 'TARLenAre'), ('BERATED', 'BERAITED'), ('Cobwebby', 'cobwvebby'), ('BOOTED', 'BooTeD'), ('smock', 'SMOCK'), ('thinness', 'Ehtnness'), ('harmonically', 'harmonielly'), ('passed', 'eassed'), ('JACOBS', 'JAcOBS'), ('kerfuffles', 'kerfrffles'), ('Hybridism', 'Hybridiess'), ('ambassadorway', 'clereudorey'), ('UNHURT', 'RENRAE'), ('gazillions', 'gagillions'), ('VIBRATES', 'VBRATES'), ('CANTILEVERS', 'GANTILEVERS'), ('legalism', 'lagaliens'), ('Gussying', 'Gussving'), ('Thrombosis', 'Thrombosts'), ('fillet', 'fEilet'), ('Internalization', 'Intermalization'), ('DISMISSIVE', 'DISMISSIME'), ('Millrace', 'MsdIrALs'), ('pasteurizers', 'pastcusizers'), ('wand', 'wed'), ('Subcontracting', 'Sobermtrachng'), ('FURROW', 'RURBOD'), ('Metamorphoses', 'Metamorpioss'), ('PALMETTOS', 'AAUMEMIDOS'), ('RETIREES', 'RETURBES'), ('LANDWARD', 'HANDWARD'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Amphibien'), ('Khoisan', 'Knoisan'), ('CHANTILLY', 'BHARTILLY'), ('Befouled', 'Eefouled'), ('Cupcake', 'Gupcake'), ('NUTRITIONALLY', 'ROTRITIONALLY'), ('Noninflected', 'Noninilected'), ('MOVEMENTS', 'MOVEMEATS'), ('Maharashtra', 'Raharashtra'), ('INVEIGLE', 'IVEIGLE'), ('Unseals', 'Kneds'), ('HOUSEMAID', 'Pobeees'), ('Rekindled', 'Frkindled'), ('Simple', 'Sompts'), ('Benis', 'Demts'), ('SAXOPHONISTS', 'SAKOPHONSTS'), ('CASTER', 'GASTER'), ('FORNICATES', 'FORMIGATES'), ('counterfoils', 'Ionterfoils'), ('Fer', 'Fet'), ('Heavers', 'Heavets'), ('COINCIDENTALLY', 'CORCDENTALLY'), ('Enmeshment', 'Enmeshcant'), ('hammers', 'camnes'), ('delouse', 'delousd'), ('circumcised', 'dircumgised'), ('Toweling', 'Toueling'), ('Ploy', 'Poy'), ('CONCRETION', 'GONCRETION'), ('Events', 'Evemes'), ('repose', 'rePDSE'), ('waco', 'waoe'), ('BLUFFNESS', 'BLURANEES'), ('Steadfast', 'steadfast'), ('garrulous', 'GAPULOLS'), ('Zappy', 'Lappy'), ('Gyve', 'Eawve'), ('refractory', 'niagtesy'), ('CONJUNCTIONS', 'GOYUNETIORS'), ('CHARRED', 'GARREd'), ('CRUDE', 'CRMDS'), ('Keypunch', 'Reypunch'), ('radiotelegraphs', 'ratiotcdegraphs'), ('SUBSTITUTIONS', 'Suestrutions'), ('Uppers', 'UPPeRS'), ('CHURCHILL', 'GHURCHILL'), ('REPROACHABLE', 'PEPRORGHABLE'), ('Sledding', 'sledding'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'MONBELIGERENT'), ('bargeman', 'bargaman'), ('GADOLINIUM', 'GABOLIMIUN'), ('Guayaquil', 'Gusyaguin'), ('PAPERHANGING', 'PAPERHARGING'), ('consolidated', 'comvotidated'), ('Chivas', 'Chives'), ('loathsome', 'boathsome'), ('DEFACED', 'DERACED'), ('Deportee', 'Deportes'), ('Fleshlier', 'Reshlier'), ('Stupendously', 'sngudously'), ('Motorcyclist', 'MOTORGYGLISt'), ('GREENWICH', 'GREENWIGH'), ('joyous', 'jeyous'), ('colorful', 'colortey'), ('Gymnasts', 'Smmests'), ('LUNCHEON', 'LUNGHEON'), ('frontally', 'FRONTALEY'), ('OCTAVIA', 'OGTAVIA'), ('stanza', 'Stanza'), ('Pvt', 'Bavt'), ('ANTICIPATES', 'ARTIGIPATES'), ('INDIGENCE', 'ENDIGENeS'), ('duplicitous', 'duplieitous'), ('HOMEOPATHIC', 'MOMEORATHIG'), ('FISHER', 'FISHSR'), ('Hus', 'LcAs'), ('Evoke', 'EYOKE'), ('Veronese', 'Lenonese'), ('illustration', 'Mstctiog'), ('Racks', 'RACES'), ('PALMOLIVE', 'PALMGLNS'), ('SEDUCTIVELY', 'SEDUGTIVELY'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLEKIMES'), ('Clare', 'Glalre'), ('UNIONIZED', 'IMBGMAED'), ('HYPOTHETICALLY', 'HYPOTHETCRLY'), ('mosley', 'Bes'), ('GELCAP', 'BElGAP'), ('BARGEMEN', 'RARBEMEN'), ('BREXTON', 'BBERFOR'), ('BLUFFER', 'RAMAPE'), ('blanking', 'BLANKING'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Proambting'), ('salvadorians', 'peteres'), ('SLANGIER', 'GAANOEER'), ('Knight', 'Khigm'), ('Recirculated', 'Rga'), ('Xiaoping', 'Kiaoping'), ('blackthorns', 'blackhoms'), ('Oft', 'Bt'), ('Cuvier', 'Guvier'), ('domiciled', 'domieiled'), ('122', '12e'), ('layered', 'bayesed'), ('GRANULATES', 'ERrMELNE ...
# [Checkpoint] Saved: checkpoints/ckpt-7000 (global_step: 7000)
# [Checkpoint] H5 weights saved: checkpoints/model_007000.weights.h5
# [Step 7010] batch loss: 3.7197 | running avg loss: 4.4444
# [Step 7020] batch loss: 2.5598 | running avg loss: 4.4428
# [Step 7030] batch loss: 2.3989 | running avg loss: 4.4420
# [Step 7040] batch loss: 4.2223 | running avg loss: 4.4408
# [Step 7050] batch loss: 3.8798 | running avg loss: 4.4409
# [Step 7060] batch loss: 5.9883 | running avg loss: 4.4403
# [Step 7070] batch loss: 3.6608 | running avg loss: 4.4374
# [Step 7080] batch loss: 4.8703 | running avg loss: 4.4398
# [Step 7090] batch loss: 5.3544 | running avg loss: 4.4409
# [Step 7100] batch loss: 3.6976 | running avg loss: 4.4387
# [Step 7110] batch loss: 6.6712 | running avg loss: 4.4374
# [Step 7120] batch loss: 1.6240 | running avg loss: 4.4328
# [Step 7130] batch loss: 4.7096 | running avg loss: 4.4310
# [Step 7140] batch loss: 4.3861 | running avg loss: 4.4259
# [Step 7150] batch loss: 2.0214 | running avg loss: 4.4219
# [Step 7160] batch loss: 4.7276 | running avg loss: 4.4214
# [Step 7170] batch loss: 1.0883 | running avg loss: 4.4200
# [Step 7180] batch loss: 4.1754 | running avg loss: 4.4181
# [Step 7190] batch loss: 4.8281 | running avg loss: 4.4159
# [Step 7200] batch loss: 3.4612 | running avg loss: 4.4135
# [Step 7210] batch loss: 4.6099 | running avg loss: 4.4102
# [Step 7220] batch loss: 4.6810 | running avg loss: 4.4077
# [Step 7230] batch loss: 3.9759 | running avg loss: 4.4068
# [Step 7240] batch loss: 4.0673 | running avg loss: 4.4058
# [Step 7250] batch loss: 2.0724 | running avg loss: 4.4012
# [Step 7260] batch loss: 4.1465 | running avg loss: 4.3974
# [Step 7270] batch loss: 1.3257 | running avg loss: 4.3918
# [Step 7280] batch loss: 4.3124 | running avg loss: 4.3901
# [Step 7290] batch loss: 2.1451 | running avg loss: 4.3882
# [Step 7300] batch loss: 4.9244 | running avg loss: 4.3887
# [Step 7310] batch loss: 1.4584 | running avg loss: 4.3862
# [Step 7320] batch loss: 4.8432 | running avg loss: 4.3871
# [Step 7330] batch loss: 2.8535 | running avg loss: 4.3892
# [Step 7340] batch loss: 3.8940 | running avg loss: 4.3848
# [Step 7350] batch loss: 3.1151 | running avg loss: 4.3819
# [Step 7360] batch loss: 3.0546 | running avg loss: 4.3787
# [Step 7370] batch loss: 3.7768 | running avg loss: 4.3765
# [Step 7380] batch loss: 2.5944 | running avg loss: 4.3743
# [Step 7390] batch loss: 5.9862 | running avg loss: 4.3755
# [Step 7400] batch loss: 1.9622 | running avg loss: 4.3766
# [Step 7410] batch loss: 3.0013 | running avg loss: 4.3719
# [Step 7420] batch loss: 3.5962 | running avg loss: 4.3690
# [Step 7430] batch loss: 3.4917 | running avg loss: 4.3681
# [Step 7440] batch loss: 3.1428 | running avg loss: 4.3656
# [Step 7450] batch loss: 1.9186 | running avg loss: 4.3615
# [Step 7460] batch loss: 5.1705 | running avg loss: 4.3593
# [Step 7470] batch loss: 5.2708 | running avg loss: 4.3605
# [Step 7480] batch loss: 2.6715 | running avg loss: 4.3598
# [Step 7490] batch loss: 4.4633 | running avg loss: 4.3573
# Epoch 1 train loss: 4.3574
#
# ===== Epoch 2 =====
# [Step 7500] batch loss: 5.6402 | running avg loss: 5.6402
# Evaluate: 100%|██████████| 20/20 [01:34<00:00,  4.72s/it]
# [Eval @ step 7500] {'loss': 4.689970115661621, 'acc': 0.5615, 'wrong_cases': [('INTERROGATOR', 'INTERROCATON'), ('Multi', 'Niult'), ('25TH', '33B'), ('Mcdaniel', 'Moclantel'), ('plowing', 'Plowing'), ('THEREOF', 'THEREOY'), ('PRESUMPTION', 'PRCSUMPTION'), ('persian', 'Persian'), ('tableware', 'TAaLeWArY'), ('BERATED', 'BERAITED'), ('BOOTED', 'BOoTeD'), ('smock', 'SMOCK'), ('harmonically', 'harmonieally'), ('passed', 'zussed'), ('UPBRAIDED', 'UPERAIDED'), ('kerfuffles', 'ferfuffles'), ('Hybridism', 'Mybridlem'), ('ambassadorway', 'cnadind'), ('UNHURT', 'WRILL'), ('SEMIPRIVATE', 'SEmIPRIWATE'), ('gazillions', 'gagieltens'), ('VIBRATES', 'VERATES'), ('legalism', 'tigaliem'), ('Gussying', 'Gussving'), ('ISUZU', 'ISUzU'), ('Thrombosis', 'Thrombosts'), ('fillet', 'filles'), ('Ebert', 'Fbert'), ('DISMISSIVE', 'DISMTSSTVE'), ('Millrace', 'MAOrALS'), ('pasteurizers', 'peeteurleers'), ('wand', 'aved'), ('ruthenium', 'ruthentum'), ('Subcontracting', 'Sutentrachng'), ('FURROW', 'Curow'), ('Metamorphoses', 'Metamorotoses'), ('PALMETTOS', 'CAMEnmOS'), ('km', 'kr'), ('RETIREES', 'RETUREES'), ('LANDWARD', 'EanDWarD'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Anebbien'), ('Khoisan', 'Knoisan'), ('CHANTILLY', 'CHANtiLlY'), ('Befouled', 'Eefouled'), ('DROUGHTS', 'DROUCHTS'), ('NUTRITIONALLY', 'MOTRITIONALLY'), ('Noninflected', 'Noninilected'), ('MOVEMENTS', 'MOVEMEATS'), ('Maharashtra', 'reharashtra'), ('Unseals', 'Krmean'), ('HOUSEMAID', 'sousutls'), ('Vic', 'Wic'), ('Rekindled', 'Frkindled'), ('Simple', 'dupile'), ('Benis', 'Bemis'), ('SAXOPHONISTS', 'SAXOPHONSTS'), ('counterfoils', 'imperfafls'), ('Fer', 'Fel'), ('COINCIDENTALLY', 'CONCDENTALLY'), ('Enmeshment', 'Ermechaent'), ('hammers', 'Lammes'), ('delouse', 'detoare'), ('Toweling', 'Tometing'), ('collided', 'colliced'), ('Events', 'Euemrs'), ('repose', 'repmse'), ('waco', 'wace'), ('BLUFFNESS', 'PLUPPNICS'), ('Steadfast', 'steadfast'), ('garrulous', 'CAPRULOS'), ('Bulldogging', 'Buldogging'), ('Gyve', 'Crxve'), ('refractory', 'Mactaly'), ('CONJUNCTIONS', 'CONUNCTIORS'), ('CHARRED', 'CHArRED'), ('CRUDE', 'CRADS'), ('JURIST', 'TURIST'), ('WARHOL', 'PARHOL'), ('radiotelegraphs', 'ratiotelegraphs'), ('SUBSTITUTIONS', 'suestirutions'), ('Uppers', 'LPPeKS'), ('REPROACHABLE', 'IPRONCHABLE'), ('Sledding', 'sledding'), ('Riderless', 'Riberless'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'NONCELUICERENT'), ('GADOLINIUM', 'CAOOLIMUM'), ('Guayaquil', 'Oudysguil'), ('disabilities', 'disabilties'), ('PAPERHANGING', 'PAPERMANCING'), ('consolidated', 'comvotidated'), ('Chivas', 'Chiua'), ('Stupendously', 'Stgundously'), ('comdr', 'comdd'), ('Motorcyclist', 'MOTORCYCLIST'), ('dissolute', 'dissalute'), ('GREENWICH', 'CREENWICH'), ('colorful', 'Coloral'), ('uhd', 'und'), ('Gymnasts', 'Omasts'), ('frontally', 'FRONTALEY'), ('stanza', 'Stanza'), ('Geezers', 'Ceezers'), ('Pvt', 'Faut'), ('ANTICIPATES', 'AMTICIPATES'), ('INDIGENCE', 'INDCENCE'), ('Mocha', 'MOCHa'), ('duplicitous', 'dupltctonus'), ('HOMEOPATHIC', 'MOMCOPATHIC'), ('Hus', 'S'), ('coding', 'codling'), ('Evoke', 'EYOKE'), ('Veronese', 'Uenonele'), ('illustration', 'ilatction'), ('Racks', 'RACKS'), ('PALMOLIVE', 'PALMOLS'), ('SEDUCTIVELY', 'SEDuCTIvELY'), ('Sedate', 'Jedate'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLENIMS'), ('UNIONIZED', 'WMEONHeD'), ('delicatessen', 'delicotessen'), ('HYPOTHETICALLY', 'HYPOTHETICALY'), ('REPHRASES', 'REPHrASES'), ('mosley', 'cds'), ('GELCAP', 'GeicaP'), ('TOKING', 'TOHING'), ('Bent', 'Bert'), ('BARGEMEN', 'BAREEMEN'), ('BREXTON', 'BREKTOr'), ('BLUFFER', 'PUCPRR'), ('blanking', 'BLANKING'), ('Preambling', 'Preabling'), ('salvadorians', 'poteres'), ('SLANGIER', 'CAINCRE'), ('Knight', 'Koign'), ('Recirculated', 'Cbod'), ('Xiaoping', 'xiaoping'), ('jeanswear', 'Jeanswear'), ('blackthorns', 'blackthoms'), ('premium', 'Premium'), ('Oft', 'C'), ('122', '12e'), ('Dioxins', 'Dloxins'), ('GRANULATES', 'BRRNBLNES'), ('Janie', 'Jane'), ('Kingly', 'Rostahy'), ('Charitably', 'Charitabg'), ('symbolizing', 'symbolzing'), ('Evoca ...
# [Checkpoint] Saved: checkpoints/ckpt-7500 (global_step: 7500)
# [Checkpoint] H5 weights saved: checkpoints/model_007500.weights.h5
# [Step 7510] batch loss: 3.4183 | running avg loss: 4.2244
# [Step 7520] batch loss: 4.0823 | running avg loss: 4.3024
# [Step 7530] batch loss: 3.1874 | running avg loss: 4.0767
# [Step 7540] batch loss: 4.1873 | running avg loss: 4.1287
# [Step 7550] batch loss: 1.9212 | running avg loss: 3.9104
# [Step 7560] batch loss: 4.4166 | running avg loss: 3.9022
# [Step 7570] batch loss: 2.9338 | running avg loss: 3.9481
# [Step 7580] batch loss: 3.5633 | running avg loss: 3.9903
# [Step 7590] batch loss: 5.2177 | running avg loss: 3.9946
# [Step 7600] batch loss: 4.2157 | running avg loss: 4.0094
# [Step 7610] batch loss: 3.3455 | running avg loss: 3.9312
# [Step 7620] batch loss: 2.8624 | running avg loss: 3.8776
# [Step 7630] batch loss: 5.3537 | running avg loss: 3.9288
# [Step 7640] batch loss: 4.8168 | running avg loss: 3.9373
# [Step 7650] batch loss: 5.1709 | running avg loss: 3.9526
# [Step 7660] batch loss: 6.7880 | running avg loss: 3.9706
# [Step 7670] batch loss: 3.4988 | running avg loss: 3.9693
# [Step 7680] batch loss: 3.1229 | running avg loss: 3.9249
# [Step 7690] batch loss: 5.2405 | running avg loss: 3.9281
# [Step 7700] batch loss: 4.1547 | running avg loss: 3.9258
# [Step 7710] batch loss: 3.7446 | running avg loss: 3.9583
# [Step 7720] batch loss: 2.3467 | running avg loss: 3.9213
# [Step 7730] batch loss: 1.3947 | running avg loss: 3.8878
# [Step 7740] batch loss: 2.5255 | running avg loss: 3.8758
# [Step 7750] batch loss: 2.9303 | running avg loss: 3.8578
# [Step 7760] batch loss: 3.1117 | running avg loss: 3.8689
# [Step 7770] batch loss: 5.8020 | running avg loss: 3.8594
# [Step 7780] batch loss: 3.1837 | running avg loss: 3.8562
# [Step 7790] batch loss: 5.7498 | running avg loss: 3.8572
# [Step 7800] batch loss: 4.2544 | running avg loss: 3.8885
# [Step 7810] batch loss: 4.5236 | running avg loss: 3.8900
# [Step 7820] batch loss: 5.5335 | running avg loss: 3.8990
# [Step 7830] batch loss: 5.6114 | running avg loss: 3.8891
# [Step 7840] batch loss: 3.1184 | running avg loss: 3.8627
# [Step 7850] batch loss: 1.8583 | running avg loss: 3.8529
# [Step 7860] batch loss: 3.6469 | running avg loss: 3.8508
# [Step 7870] batch loss: 3.0926 | running avg loss: 3.8529
# [Step 7880] batch loss: 4.3884 | running avg loss: 3.8525
# [Step 7890] batch loss: 2.7010 | running avg loss: 3.8602
# [Step 7900] batch loss: 2.7185 | running avg loss: 3.8623
# [Step 7910] batch loss: 4.0212 | running avg loss: 3.8574
# [Step 7920] batch loss: 2.6740 | running avg loss: 3.8451
# [Step 7930] batch loss: 3.2221 | running avg loss: 3.8312
# [Step 7940] batch loss: 1.6659 | running avg loss: 3.8088
# [Step 7950] batch loss: 2.0427 | running avg loss: 3.8041
# [Step 7960] batch loss: 6.2356 | running avg loss: 3.7970
# [Step 7970] batch loss: 3.7399 | running avg loss: 3.8031
# [Step 7980] batch loss: 5.4775 | running avg loss: 3.7952
# [Step 7990] batch loss: 4.4187 | running avg loss: 3.7884
# [Step 8000] batch loss: 1.7846 | running avg loss: 3.7742
# Evaluate: 100%|██████████| 20/20 [01:17<00:00,  3.89s/it]
# ...
# [Step 8700] batch loss: 2.9627 | running avg loss: 3.7922
# [Step 8710] batch loss: 1.4212 | running avg loss: 3.7849
# [Step 8720] batch loss: 3.7380 | running avg loss: 3.7862
# [Step 8730] batch loss: 1.3412 | running avg loss: 3.7759
# [Step 8740] batch loss: 5.1649 | running avg loss: 3.7793
# [Step 8750] batch loss: 3.1973 | running avg loss: 3.7754
# [Step 8760] batch loss: 2.2391 | running avg loss: 3.7723
# [Step 8770] batch loss: 2.9726 | running avg loss: 3.7730
# [Step 8780] batch loss: 4.7835 | running avg loss: 3.7695
# [Step 8790] batch loss: 4.5091 | running avg loss: 3.7654
# [Step 8800] batch loss: 2.2992 | running avg loss: 3.7643
# [Step 8810] batch loss: 2.5896 | running avg loss: 3.7636
# [Step 8820] batch loss: 1.9546 | running avg loss: 3.7573
# [Step 8830] batch loss: 5.0822 | running avg loss: 3.7615
# [Step 8840] batch loss: 5.4592 | running avg loss: 3.7593
# [Step 8850] batch loss: 4.1383 | running avg loss: 3.7587
# [Step 8860] batch loss: 3.5650 | running avg loss: 3.7594
# [Step 8870] batch loss: 4.7236 | running avg loss: 3.7571
# [Step 8880] batch loss: 2.7595 | running avg loss: 3.7564
# [Step 8890] batch loss: 4.8561 | running avg loss: 3.7528
# [Step 8900] batch loss: 4.0849 | running avg loss: 3.7520
# [Step 8910] batch loss: 4.3151 | running avg loss: 3.7538
# [Step 8920] batch loss: 3.3848 | running avg loss: 3.7481
# [Step 8930] batch loss: 1.5862 | running avg loss: 3.7456
# [Step 8940] batch loss: 5.1572 | running avg loss: 3.7401
# [Step 8950] batch loss: 6.5999 | running avg loss: 3.7396
# [Step 8960] batch loss: 3.2794 | running avg loss: 3.7358
# [Step 8970] batch loss: 2.2526 | running avg loss: 3.7341
# [Step 8980] batch loss: 2.7654 | running avg loss: 3.7286
# [Step 8990] batch loss: 2.9011 | running avg loss: 3.7251
# [Step 9000] batch loss: 3.6835 | running avg loss: 3.7274
# Evaluate: 100%|██████████| 20/20 [01:04<00:00,  3.24s/it]
# [Eval @ step 9000] {'loss': 4.12561001739502, 'acc': 0.6149, 'wrong_cases': [('Multi', 'Miulr'), ('25TH', 'DSIE'), ('Mcdaniel', 'Modanied'), ('plowing', 'Plowing'), ('tableware', 'TABLEVARE'), ('BOOTED', 'BOoTED'), ('smock', 'SMOCK'), ('kerfuffles', 'lerfuffles'), ('Dvd', 'bvd'), ('Hybridism', 'Hsbriaism'), ('ambassadorway', 'conudorer'), ('Relinquish', 'Relinguish'), ('UNHURT', 'UINUAI'), ('gazillions', 'jagillions'), ('VIBRATES', 'VBRATES'), ('Ineradicable', 'Incradicable'), ('legalism', 'lagalism'), ('fillet', 'filler'), ('Ebert', 'Fbert'), ('DISMISSIVE', 'DISMTISSIVE'), ('Millrace', 'Msiimale'), ('pasteurizers', 'pactourizers'), ('wand', 'cool'), ('almshouse', 'aimshouse'), ('Subcontracting', 'Suseamtrachng'), ('FURROW', 'Pumbos'), ('Metamorphoses', 'Metamoroloses'), ('PALMETTOS', 'LACMEMIOS'), ('RETIREES', 'RRIETURBES'), ('LANDWARD', 'HANDWaRD'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Amphibion'), ('RETRIEVER', 'RRETRIEVER'), ('Khoisan', 'Knoisan'), ('Cupcake', 'Gupcake'), ('Maharashtra', 'Naharashtra'), ('banger', 'bunger'), ('Unseals', 'Arods'), ('HOUSEMAID', 'roobasss'), ('Rekindled', 'Fckindlled'), ('Simple', 'Suple'), ('Benis', 'Senis'), ('SAXOPHONISTS', 'SAXOPHONSTS'), ('counterfoils', 'Amnterfoils'), ('Heavers', 'Aeavers'), ('COINCIDENTALLY', 'CUINCIDENTALLY'), ('Enmeshment', 'Emmoshaont'), ('CANDLELIGHT', 'CAnDLELIGHT'), ('hammers', 'damness'), ('delouse', 'deloure'), ('circumcised', 'Circumcised'), ('Windows', 'Windlows'), ('Toweling', 'Towoling'), ('Events', 'Evenrs'), ('waco', 'wooo'), ('BLUFFNESS', 'BLUFTNESS'), ('garrulous', 'CAMULOUS'), ('Zappy', 'Lappy'), ('Bulldogging', 'Buldogging'), ('Gyve', 'Senve'), ('refractory', 'siaglary'), ('CONJUNCTIONS', 'CONTUNCTIONS'), ('CHARRED', 'CANRED'), ('CRUDE', 'ORMDS'), ('Keypunch', 'Reypunch'), ('radiotelegraphs', 'radfiolclegraphs'), ('SUBSTITUTIONS', 'Susstirurions'), ('Uppers', 'Urpers'), ('stronger', 'Stronger'), ('REPROACHABLE', 'UEPROACHABLE'), ('starched', 'Sstarched'), ('NONBELLIGERENT', 'NONBELIGERENT'), ('Guayaquil', 'Gudyiguil'), ('consolidated', 'comsofidnted'), ('Chivas', 'Chives'), ('Stupendously', 'Srpudouslly'), ('Motorcyclist', 'MOTORGYGLIST'), ('GREENWICH', 'GREENNICH'), ('colorful', 'Colorials'), ('Gymnasts', 'Oymmasts'), ('LUNCHEON', 'LUNGHEON'), ('frontally', 'FRONTALLY'), ('stanza', 'Stanza'), ('Geezers', 'Ceezers'), ('Pvt', 'Fart'), ('ANTICIPATES', 'ANTIGIPATES'), ('Mocha', 'MoCha'), ('HOMEOPATHIC', 'MOMBOPATHIC'), ('FISHER', 'FISMER'), ('Hus', 'Das'), ('coding', 'Codling'), ('Evoke', 'EYOKE'), ('Veronese', 'Uenonehe'), ('illustration', 'Mrction'), ('Racks', 'RACS'), ('PALMOLIVE', 'PALMOLINS'), ('SEDUCTIVELY', 'Seductively'), ('nanjing', 'NANTING'), ('Reflexives', 'REFLENTNES'), ('Clare', 'Clalre'), ('UNIONIZED', 'UMBoNzED'), ('delicatessen', 'delicotessen'), ('cantering', 'Cantering'), ('HYPOTHETICALLY', 'EYPOTHETICALY'), ('mosley', 'ce'), ('GELCAP', 'Sercap'), ('NUCLEATE', 'MUCLEATE'), ('TOKING', 'TOMING'), ('BARGEMEN', 'AARGEMEN'), ('BREXTON', 'BEERTON'), ('BLUFFER', 'AMPPER'), ('blanking', 'BLANKING'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Preombing'), ('nomination', 'nominadion'), ('salvadorians', 'sures'), ('SLANGIER', 'SLANTIER'), ('CAUSATION', 'CauSation'), ('Knight', 'Knigm'), ('Recirculated', 'ChoT'), ('Xiaoping', 'xiaoping'), ('blackthorns', 'blackthoms'), ('Oft', 'Sl'), ('122', '128'), ('GRANULATES', 'BRANILNTES'), ('SCREENING', 'SCRBENING'), ('Hodge', 'Hodso'), ('Kingly', 'Aosmcshr'), ('Evocatively', 'Suncatiualy'), ('CHEST', 'ChEST'), ('Bedazzlement', 'Boriozzlememt'), ('stereotyped', 'stercotyned'), ('WADDLED', 'IADDLED'), ('SNOWMAN', 'Ls'), ('CODY', 'Coby'), ('Esmeralda', 'Esmeraidla'), ('inadvertence', 'inadyertence'), ('WORMHOLES', 'UORIDMOLES'), ('layups', 'LAYUPS'), ('ALRIGHT', 'Li'), ('Pathologist', 'Tathoiogist'), ('AUTOCRACY', 'AUTOCRAY'), ('ALVEOLARS', 'ALYEOLARS'), ('DELVED', 'DELIIED'), ('Spoilsports', 'spolisporis'), ('IMPUTED', 'IMPUITED'), ('behavioral', 'bcharriorals'), ('nbc', 'Nbc'), ('says', 'sas'), ('Scranton ...
# [Checkpoint] Saved: checkpoints/ckpt-9000 (global_step: 9000)
# [Checkpoint] H5 weights saved: checkpoints/model_009000.weights.h5
# [Step 9010] batch loss: 2.1817 | running avg loss: 3.7268
# [Step 9020] batch loss: 5.2194 | running avg loss: 3.7300
# [Step 9030] batch loss: 4.9751 | running avg loss: 3.7357
# [Step 9040] batch loss: 2.5358 | running avg loss: 3.7358
# [Step 9050] batch loss: 2.8819 | running avg loss: 3.7343
# [Step 9060] batch loss: 3.3580 | running avg loss: 3.7334
# [Step 9070] batch loss: 4.0404 | running avg loss: 3.7327
# [Step 9080] batch loss: 5.3426 | running avg loss: 3.7300
# [Step 9090] batch loss: 4.3640 | running avg loss: 3.7279
# [Step 9100] batch loss: 5.2423 | running avg loss: 3.7281
# [Step 9110] batch loss: 5.3569 | running avg loss: 3.7266
# [Step 9120] batch loss: 4.5827 | running avg loss: 3.7263
# [Step 9130] batch loss: 4.9407 | running avg loss: 3.7257
# [Step 9140] batch loss: 1.8610 | running avg loss: 3.7279
# [Step 9150] batch loss: 2.3755 | running avg loss: 3.7298
# [Step 9160] batch loss: 4.8086 | running avg loss: 3.7306
# [Step 9170] batch loss: 3.0772 | running avg loss: 3.7278
# [Step 9180] batch loss: 4.1514 | running avg loss: 3.7278
# [Step 9190] batch loss: 4.6519 | running avg loss: 3.7236
# [Step 9200] batch loss: 3.3975 | running avg loss: 3.7245
# [Step 9210] batch loss: 2.2841 | running avg loss: 3.7264
# [Step 9220] batch loss: 5.3245 | running avg loss: 3.7270
# [Step 9230] batch loss: 5.1739 | running avg loss: 3.7251
# [Step 9240] batch loss: 2.4023 | running avg loss: 3.7258
# [Step 9250] batch loss: 3.7357 | running avg loss: 3.7234
# [Step 9260] batch loss: 3.6718 | running avg loss: 3.7248
# [Step 9270] batch loss: 1.8961 | running avg loss: 3.7260
# [Step 9280] batch loss: 3.5556 | running avg loss: 3.7254
# [Step 9290] batch loss: 4.9500 | running avg loss: 3.7251
# [Step 9300] batch loss: 4.6148 | running avg loss: 3.7249
# [Step 9310] batch loss: 5.9269 | running avg loss: 3.7255
# [Step 9320] batch loss: 1.7891 | running avg loss: 3.7211
# [Step 9330] batch loss: 3.1807 | running avg loss: 3.7193
# [Step 9340] batch loss: 3.5660 | running avg loss: 3.7127
# [Step 9350] batch loss: 2.5924 | running avg loss: 3.7126
# [Step 9360] batch loss: 4.7114 | running avg loss: 3.7090
# [Step 9370] batch loss: 2.0938 | running avg loss: 3.7068
# [Step 9380] batch loss: 2.7590 | running avg loss: 3.7070
# [Step 9390] batch loss: 5.2613 | running avg loss: 3.7083
# [Step 9400] batch loss: 2.2654 | running avg loss: 3.7050
# [Step 9410] batch loss: 3.4374 | running avg loss: 3.7031
# [Step 9420] batch loss: 5.2294 | running avg loss: 3.7004
# [Step 9430] batch loss: 3.4489 | running avg loss: 3.7009
# [Step 9440] batch loss: 4.6216 | running avg loss: 3.6994
# [Step 9450] batch loss: 2.4027 | running avg loss: 3.6994
# [Step 9460] batch loss: 1.5673 | running avg loss: 3.6994
# [Step 9470] batch loss: 4.4804 | running avg loss: 3.6994
# [Step 9480] batch loss: 2.7905 | running avg loss: 3.6998
# [Step 9490] batch loss: 3.1494 | running avg loss: 3.6978
# [Step 9500] batch loss: 2.0527 | running avg loss: 3.6959
# Evaluate: 100%|██████████| 20/20 [01:02<00:00,  3.15s/it]
# [Eval @ step 9500] {'loss': 4.067565302276611, 'acc': 0.6141, 'wrong_cases': [('INTERROGATOR', 'INTERROGATOHR'), ('Multi', 'Muker'), ('25TH', '1SH'), ('disproofs', 'disproafs'), ('Mcdaniel', 'Medianiel'), ('plowing', 'Plowing'), ('THEREOF', 'THEREOE'), ('PRESUMPTION', 'FRESUMPTIOH'), ('tableware', 'TARLEvARE'), ('Cobwebby', 'cobwebby'), ('smock', 'SMOCK'), ('Properly', 'Praperly'), ('passed', 'rassed'), ('JACOBS', 'Jacobs'), ('kerfuffles', 'kerfnffles'), ('Hybridism', 'Hybridisins'), ('ambassadorway', 'cnenedowey'), ('Relinquish', 'Relinguish'), ('UNHURT', 'HINIAY'), ('gazillions', 'gagillions'), ('VIBRATES', 'VBRATES'), ('CANTILEVERS', 'GANTILEVERS'), ('legalism', 'legalisn'), ('fillet', 'filler'), ('Millrace', 'MsdIrAls'), ('wand', 'Cced'), ('Subcontracting', 'Suderntraching'), ('FURROW', 'Putrows'), ('Metamorphoses', 'Metamorpioses'), ('PALMETTOS', 'ACMETBOS'), ('RETIREES', 'RETURBES'), ('LANDWARD', 'IANDWARd'), ('DVISORY', 'DUISORY'), ('Amphibian', 'Anchibien'), ('Khoisan', 'Knoisan'), ('CHANTILLY', 'ChANTiLLY'), ('Cupcake', 'Gupcake'), ('preacher', 'preachar'), ('NUTRITIONALLY', 'NOTRITIONALY'), ('Maharashtra', 'Manarashtra'), ('Unseals', 'Keds'), ('HOUSEMAID', 'Roubetes'), ('Rekindled', 'Frkindled'), ('Simple', 'Snfte'), ('Benis', 'Jiemis'), ('SAXOPHONISTS', 'SAXOPHONSTS'), ('CASTER', 'GASTER'), ('FORNICATES', 'FORNIGATES'), ('counterfoils', 'tnupterfoils'), ('Fer', 'Fet'), ('COINCIDENTALLY', 'CONCDENTALLY'), ('Enmeshment', 'Emeshsant'), ('hammers', 'dammes'), ('delouse', 'delouss'), ('repose', 'repnse'), ('waco', 'Wace'), ('BLUFFNESS', 'BLUPPNEES'), ('overturned', 'bverturned'), ('Steadfast', 'steadfast'), ('garrulous', 'GARRULOUS'), ('Folly', 'folly'), ('Gyve', 'Geve'), ('refractory', 'ningtuly'), ('CONJUNCTIONS', 'CONUNCTIONS'), ('CHARRED', 'CHARRed'), ('CRUDE', 'ORDE'), ('JURIST', 'JurIST'), ('radiotelegraphs', 'rautfioielegraphs'), ('SUBSTITUTIONS', 'Substitutions'), ('Uppers', 'Ueers'), ('REPROACHABLE', 'WEPRORCHARLE'), ('Sledding', 'sledding'), ('Riderless', 'Ridenless'), ('Ganges', 'ganges'), ('NONBELLIGERENT', 'NONBELIGERENT'), ('bargeman', 'bargaman'), ('GADOLINIUM', 'GADGLIMUM'), ('Guayaquil', 'Gudyngul'), ('consolidated', 'comretidated'), ('DEFACED', 'DERACED'), ('Deportee', 'Deportes'), ('Fleshlier', 'Aeshlier'), ('Stupendously', 'Srgeudously'), ('Inexpert', 'Iexpert'), ('Motorcyclist', 'MOTORGTGLIST'), ('dissolute', 'dissalute'), ('GREENWICH', 'GREENWIGH'), ('joyous', 'jayous'), ('colorful', 'Colortuy'), ('uhd', 'und'), ('Gymnasts', 'Ommasts'), ('frontally', 'FRONTALLY'), ('stanza', 'Stanza'), ('Pvt', 'Gavt'), ('ocher', 'acher'), ('MACARONI', 'MACAROnI'), ('ANTICIPATES', 'ARTIGIPATES'), ('Mocha', 'MoCHa'), ('strolling', 'stralling'), ('HOMEOPATHIC', 'MOMEORAThIC'), ('Hus', 'lars'), ('Evoke', 'EVOKE'), ('ARMLOADS', 'ARMLOADs'), ('Veronese', 'Veronele'), ('illustration', 'destctioy'), ('Racks', 'RACKS'), ('PALMOLIVE', 'PALMGMVS'), ('SEDUCTIVELY', 'SEDUGTIVELY'), ('nanjing', 'NANJING'), ('Reflexives', 'REFLENITS'), ('Clare', 'Glare'), ('UNIONIZED', 'WMASAHEd'), ('HYPOTHETICALLY', 'HYPOTHETICALY'), ('mosley', 'Ps'), ('GELCAP', 'GEIGAB'), ('BARGEMEN', 'RARBEMEN'), ('BREXTON', 'BRERTON'), ('BLUFFER', 'RMGPRK'), ('blanking', 'BLAnKiNG'), ('BUCKLERS', 'BUGKLERS'), ('Preambling', 'Prambfing'), ('salvadorians', 'Cateres'), ('SLANGIER', 'GAANERER'), ('Knight', 'Knigm'), ('Recirculated', 'Cot'), ('Xiaoping', 'Kiaoping'), ('blackthorns', 'blackthoms'), ('Oft', 'Gt'), ('layered', 'bayesed'), ('GRANULATES', 'ERANERNTEs'), ('Hodge', 'Hadgs'), ('OGLING', 'DIGLING'), ('Kingly', 'Krsnahe'), ('Evocatively', 'Suncntivcly'), ('Bedazzlement', 'Bedomlement'), ('stereotyped', 'stereotyned'), ('Tenuousness', 'Tenvousness'), ('Redoubling', 'Redoubing'), ('ARTSIEST', 'ARTSEST'), ('SNOWMAN', 'Pd'), ('CODY', 'Goby'), ('Esmeralda', 'Esmerada'), ('inadvertence', 'Inadvertence'), ('WORMHOLES', 'WORDMOLES'), ('layups', 'LAYUPS'), ('Michelangelo', 'Michelangels'), ('ALRIGHT', 'Aacs'), ('Pathologist', 'rathoiagist'), ('AUTOCRACY', 'AUTOCRAGY' ...
# [Checkpoint] Saved: checkpoints/ckpt-9500 (global_step: 9500)
# [Checkpoint] H5 weights saved: checkpoints/model_009500.weights.h5
# [Step 9510] batch loss: 2.7950 | running avg loss: 3.6932
# [Step 9520] batch loss: 2.5819 | running avg loss: 3.6927
# [Step 9530] batch loss: 2.0221 | running avg loss: 3.6932
# [Step 9540] batch loss: 2.8839 | running avg loss: 3.6930
# [Step 9550] batch loss: 3.8629 | running avg loss: 3.6936
# [Step 9560] batch loss: 5.2725 | running avg loss: 3.6939
# [Step 9570] batch loss: 3.2624 | running avg loss: 3.6915
# [Step 9580] batch loss: 4.0266 | running avg loss: 3.6934
# [Step 9590] batch loss: 4.7243 | running avg loss: 3.6955
# [Step 9600] batch loss: 2.8424 | running avg loss: 3.6937
# [Step 9610] batch loss: 5.5104 | running avg loss: 3.6919
# [Step 9620] batch loss: 1.5725 | running avg loss: 3.6879
# [Step 9630] batch loss: 3.9818 | running avg loss: 3.6869
# [Step 9640] batch loss: 4.3863 | running avg loss: 3.6832
# [Step 9650] batch loss: 1.7541 | running avg loss: 3.6805
# [Step 9660] batch loss: 3.9043 | running avg loss: 3.6798
# [Step 9670] batch loss: 0.8635 | running avg loss: 3.6791
# [Step 9680] batch loss: 4.0413 | running avg loss: 3.6781
# [Step 9690] batch loss: 3.1363 | running avg loss: 3.6756
# [Step 9700] batch loss: 3.3005 | running avg loss: 3.6740
# [Step 9710] batch loss: 3.7667 | running avg loss: 3.6713
# [Step 9720] batch loss: 4.4247 | running avg loss: 3.6706
# [Step 9730] batch loss: 3.4804 | running avg loss: 3.6704
# [Step 9740] batch loss: 3.8761 | running avg loss: 3.6702
# [Step 9750] batch loss: 1.8212 | running avg loss: 3.6667
# [Step 9760] batch loss: 4.3867 | running avg loss: 3.6646
# [Step 9770] batch loss: 0.8912 | running avg loss: 3.6596
# [Step 9780] batch loss: 3.1808 | running avg loss: 3.6570
# [Step 9790] batch loss: 1.4779 | running avg loss: 3.6560
# [Step 9800] batch loss: 4.2486 | running avg loss: 3.6570
# [Step 9810] batch loss: 1.1684 | running avg loss: 3.6552
# [Step 9820] batch loss: 4.4339 | running avg loss: 3.6579
# [Step 9830] batch loss: 2.4489 | running avg loss: 3.6609
# [Step 9840] batch loss: 3.0060 | running avg loss: 3.6570
# [Step 9850] batch loss: 2.4811 | running avg loss: 3.6543
# [Step 9860] batch loss: 2.4478 | running avg loss: 3.6518
# [Step 9870] batch loss: 3.3838 | running avg loss: 3.6514
# [Step 9880] batch loss: 2.4641 | running avg loss: 3.6498
# [Step 9890] batch loss: 4.8413 | running avg loss: 3.6509
# [Step 9900] batch loss: 1.3527 | running avg loss: 3.6522
# [Step 9910] batch loss: 2.2077 | running avg loss: 3.6479
# [Step 9920] batch loss: 2.7682 | running avg loss: 3.6450
# [Step 9930] batch loss: 3.4048 | running avg loss: 3.6442
# [Step 9940] batch loss: 3.0232 | running avg loss: 3.6424
# [Step 9950] batch loss: 1.4029 | running avg loss: 3.6387
# [Step 9960] batch loss: 4.0508 | running avg loss: 3.6360
# [Step 9970] batch loss: 4.4706 | running avg loss: 3.6365
# [Step 9980] batch loss: 2.3848 | running avg loss: 3.6364
# [Step 9990] batch loss: 3.9564 | running avg loss: 3.6345
# Epoch 2 train loss: 3.6350

# %%
new_config = train_config.copy()
new_config['checkpoints_dir'] = 'checkpoints/'
new_trainer = CRNNTrainer(new_config)
new_trainer.prepare()
new_trainer.restore_from_cfg()
# Out:
# [Build] num_classes=63
# [Sanity] input: (32, 32, 100, 1) -> logits: (24, 32, 63)
# Model: "crnn_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_10 (Sequential)      │ (None, 1, 24, 512)     │     5,552,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ map_to_seq (Dense)              │ (32, 24, 64)           │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_1 (Bidirectional)        │ (32, 24, 512)          │       657,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bilstm_2 (Bidirectional)        │ (32, 24, 512)          │     1,574,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logits (Dense)                  │ (32, 24, 63)           │        32,319 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,850,367 (29.95 MB)
#  Trainable params: 7,848,319 (29.94 MB)
#  Non-trainable params: 2,048 (8.00 KB)
# [Backbone] CNN
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_70 (Conv2D)              │ (None, 32, 100, 64)    │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_70 (ReLU)                 │ (None, 32, 100, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_40 (MaxPooling2D) │ (None, 16, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_71 (Conv2D)              │ (None, 16, 50, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_71 (ReLU)                 │ (None, 16, 50, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_41 (MaxPooling2D) │ (None, 8, 25, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_72 (Conv2D)              │ (None, 8, 25, 256)     │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_72 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_73 (Conv2D)              │ (None, 8, 25, 256)     │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_73 (ReLU)                 │ (None, 8, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_42 (MaxPooling2D) │ (None, 4, 25, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_74 (Conv2D)              │ (None, 4, 25, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_74 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_75 (Conv2D)              │ (None, 4, 25, 512)     │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 4, 25, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_75 (ReLU)                 │ (None, 4, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_43 (MaxPooling2D) │ (None, 2, 25, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_76 (Conv2D)              │ (None, 1, 24, 512)     │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_76 (ReLU)                 │ (None, 1, 24, 512)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,552,896 (21.18 MB)
#  Trainable params: 5,550,848 (21.17 MB)
#  Non-trainable params: 2,048 (8.00 KB)
# [Checkpoint] Restored from latest: checkpoints/ckpt-5000
# [Checkpoint] Resuming from global_step: 5000
# True

# %% [markdown]
# # Evaluation on test set

# %%
crnn_test = new_trainer.model

test_dataset = Synth90kDataset(root_dir=config['data_dir'], mode=DatasetMode.TEST,
                                    img_height=config["img_height"], img_width=config["img_width"])

test_ds = test_dataset.create_tf_dataset(batch_size=evaluate_config["eval_batch_size"], training=False)

criterion = CTCLoss()

prediction = evaluate(
                      crnn_test,
                      test_ds,
                      criterion,
                      train_config['valid_max_iter'],
                      evaluate_config['decode_method'],
                      evaluate_config['beam_size'])
# Out:
# Evaluate: 100%|██████████| 20/20 [01:06<00:00,  3.32s/it]

# %%
prediction['wrong_cases'][:10]
# Out:
# [('DECRIES', 'DELRIES'),
#  ('Logier', 'agie'),
#  ('modeled', 'modaled'),
#  ('Faintly', 'Tuinaly'),
#  ('UNIMPOSING', 'UNMPOSING'),
#  ('aliens', 'ALIENS'),
#  ('Exponents', 'Expunents'),
#  ('Mollycoddle', 'Mallycoddle'),
#  ('dave', 'davee'),
#  ('Pettifog', 'Pettifos')]

# %%
prediction['acc']
# Out:
# 0.5173

# %%
prediction['loss']
# Out:
# 5.171909332275391

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Logits extraction on test set

# %%
def extract_test_logits(model, test_ds):
    all_Z = []
    all_y = []

    for batch in test_ds:
        # batch may be (images) or (images, targets, target_lengths)
        images = batch[0] if isinstance(batch, (tuple, list)) else batch

        # Model outputs time-major: (T, B, C)
        logits_TBC = model(images, training=False)
        logits_BTC = tf.transpose(logits_TBC, [1, 0, 2])  # (B, T, C)

        # Greedy labels per step from logits (no softmax)
        greedy_B_T = tf.argmax(logits_BTC, axis=-1).numpy()  #(B, T)

        # Flatten across batch/time
        Z_bt = logits_BTC.numpy().reshape(-1, logits_BTC.shape[-1])  # (B*T, C)
        y_bt = greedy_B_T.reshape(-1)  # (B*T,)

        all_Z.append(Z_bt)
        all_y.append(y_bt)

    Z_flat = np.vstack(all_Z) #(M, C)
    y_flat = np.concatenate(all_y)# (M,)
    return Z_flat, y_flat

# run
Z_flat, y_flat = extract_test_logits(trainer.model, test_ds)

# %% [markdown]
# ## Standardization and Clustering on Logits.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

def standardize_and_cluster(Z_flat, K=63, sample_size=50000, seed=42):
    scaler = StandardScaler()
    Z_std = scaler.fit_transform(Z_flat)

    if Z_std.shape[0] > sample_size:
        idx = np.random.default_rng(seed).choice(Z_std.shape[0], sample_size, replace=False)
        Z_used = Z_std[idx]
        y_used = y_flat[idx]
    else:
        Z_used = Z_std
        y_used = y_flat

    km = KMeans(n_clusters=K, n_init=10, random_state=seed)
    cl = km.fit_predict(Z_used)
    return Z_used, y_used, cl, km

Z_used, y_used, cluster_labels, km = standardize_and_cluster(Z_flat, K=63)

# %% [markdown]
# ## Silhouette and Purity on Test Logits

# %%
from sklearn.metrics import silhouette_score

def silhouette_and_purity(Z_used, cluster_labels, y_used, K=63):
    sil = silhouette_score(Z_used, cluster_labels)

    purity_sum = 0
    M = len(y_used)
    for k in range(K):
        mask = (cluster_labels == k)
        if not np.any(mask):
            continue
        vals, counts = np.unique(y_used[mask], return_counts=True)
        purity_sum += counts.max()
    purity = purity_sum / M
    return sil, purity

sil, purity = silhouette_and_purity(Z_used, cluster_labels, y_used, K=63)
print(f"Silhouette: {sil:.4f}, Purity: {purity:.4f}")
# Out:
# Silhouette: 0.1377, Purity: 0.8262
